# %%
import requests
import urllib.parse
import pickle
import time
import os

# %%
class MetaDataStore(dict):
    """ Store and get the metadata from Crossref
    """
    
    def __init__(self, cachelocation = 'data/cachefile.pickle'):
        """ Load the cached metadata from the `cachelocation` filename
        """
        self.cachelocation = cachelocation
        self.mailadress = 'xdze2.me@gmail.com'
        
        try:
            with open(cachelocation, 'rb') as f:
                self.update( pickle.load(f) )
                
            print( len(self), 'metadata loaded from `%s`' % cachelocation )
        
        except FileNotFoundError:
            print( '`%s` not found. A new file will be created.' % cachelocation  )

        
    def __missing__(self, doi):
        """ Perform automatically the query on Crossref if missing
            update the cache and save to the pickle file
        """
        
        url = 'https://api.crossref.org/works/'
        params = { 'mailto':self.mailadress }
        parsed_url = url + urllib.parse.quote_plus( doi )
        
        response = requests.get(parsed_url, params=params)
        
        if not response.ok:
            print('`%s` not found. Empty metadata created. ' % doi)
            #raise NameError('query error: %s' % response.url )
            metadata = {'DOI': doi}
        else:
            print( 'metadata retrieved from Crossref in %.3f s.' % response.elapsed.total_seconds() )
            response = response.json()
            metadata = response['message']
            
        self[doi] = metadata
        
        # save to file, create if not exist
        os.makedirs(os.path.dirname(self.cachelocation), exist_ok=True)
        with open(self.cachelocation, 'wb') as f:
            pickle.dump(self, f)

            
        return MetaData( metadata )
        
        
    def __getitem__(self, key):
        """ Wrap the returned value in a MetaData object
        """
        value = dict.__getitem__(self, key)
        return  MetaData( value )
    
    
    def reset(self):
        """ Empty the cache and delete the cache file
        """
        cachesize = os.path.getsize(self.cachelocation) / 1024**2
        message = 'Delete `{}` {:.2f} Mo, \n Are you sure? [type yes] '
        confirm = input( message.format(self.cachelocation, cachesize ) )
        
        if confirm == 'yes':
            self.clear()
            os.remove(self.cachelocation)
            print('file removed')
        else:
            print('canceled')

# %%
class MetaData(dict):
    """ Class based on a dict representing the metadata
    """
    
    def __init__(self, metadata):
        self.update( metadata )
        
    @property
    def refs_doi(self):
        """ List of doi of the references
        """
        references = self.get('reference', [])
        referencesWithDoi = { ref['DOI'] for ref in references if 'DOI' in ref }
        
        return list( referencesWithDoi )
    
    
    @property
    def label(self):
        """ Label for the article as AuthorYEAR
            return part of the hash is no metadata is found
        """        
        try:
            year = self['issued']['date-parts'][0][0]
            familyname = [ auth['family'] for auth in self['author'] if auth['sequence']=='first'][0]

            label = familyname + str(year)
        except KeyError:
            label = str( abs(hash( self['DOI'] )) )[:5]
            
        return label
    
    
    def __str__(self):
        """ Return nicely formated metadata
        """
        try:
            title = self['title'][0]
            title = (title[:75].strip() + '...') if len(title) > 75 else title

            year = self['issued']['date-parts'][0][0]
            
            first_author = ' '.join([ (auth['given'], auth['family'])
                                     for auth in self['author']
                                     if auth['sequence']=='first'][0] )
            
            journal = self.get('container-title', '')[0]
            
            info = '({year}) {title}\n'.format(year=year, title=title)
            info += '   ' + first_author + ' et al.'
            info += ' - ' + journal
            info += '\n   ' + self['URL']
            
        except KeyError:
            info = '[%s] no meta data :(' % self['DOI']
        
        return info

# %%
store = MetaDataStore('cache/cache.pickle')
# Out:
# 2 metadata loaded from `cache/cache.pickle`

# %%
store.reset()
# Out:
# Delete `cache/cache.pickle` 0.01 Mo,
#  Are you sure? [type yes] no
# canceled

# %%
store.keys()
# Out:
# dict_keys(['10.1063/1.113684', '10.1063/1.113681', '10.1063/1.113680'])

# %%
store['10.1063/1.113681']
# Out:
# metadata retrieved from Crossref in 0.625 s.
# {'DOI': '10.1063/1.113681',
#  'ISSN': ['0003-6951', '1077-3118'],
#  'URL': 'http://dx.doi.org/10.1063/1.113681',
#  'alternative-id': ['10.1063/1.113681'],
#  'author': [{'affiliation': [],
#    'family': 'Feng',
#    'given': 'J.',
#    'sequence': 'first'},
#   {'affiliation': [],
#    'family': 'Chen',
#    'given': 'T. R.',
#    'sequence': 'additional'},
#   {'affiliation': [],
#    'family': 'Zhao',
#    'given': 'B.',
#    'sequence': 'additional'},
#   {'affiliation': [],
#    'family': 'Yariv',
#    'given': 'A.',
#    'sequence': 'additional'}],
#  'container-title': ['Applied Physics Letters'],
#  'content-domain': {'crossmark-restriction': False, 'domain': []},
#  'created': {'date-parts': [[2002, 7, 26]],
#   'date-time': '2002-07-26T12:27:32Z',
#   'timestamp': 1027686452000},
#  'deposited': {'date-parts': [[2016, 12, 29]],
#   'date-time': '2016-12-29T03:46:40Z',
#   'timestamp': 1482983200000},
#  'indexed': {'date-parts': [[2018, 5, 3]],
#   'date-time': '2018-05-03T03:45:56Z',
#   'timestamp': 1525319156954},
#  'is-referenced-by-count': 1,
#  'issn-type': [{'type': 'print', 'value': '0003-6951'},
#   {'type': 'electronic', 'value': '1077-3118'}],
#  'issue': '16',
#  'issued': {'date-parts': [[1995, 4, 17]]},
#  'journal-issue': {'issue': '16',
#   'published-print': {'date-parts': [[1995, 4, 17]]}},
#  'language': 'en',
#  'link': [{'URL': 'http://aip.scitation.org/doi/pdf/10.1063/1.113681',
#    'content-type': 'unspecified',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'member': '317',
#  'original-title': [],
#  'page': '2028-2030',
#  'prefix': '10.1063',
#  'published-print': {'date-parts': [[1995, 4, 17]]},
#  'publisher': 'AIP Publishing',
#  'reference': [{'author': 'Kogelink',
#    'first-page': '152',
#    'key': '10.1063/1.113681_r1',
#    'volume': '18',
#    'year': '1971'},
#   {'author': 'Nakamara,',
#    'first-page': '487',
#    'key': '10.1063/1.113681_r2',
#    'volume': '25',
#    'year': '1974'},
#   {'author': 'Soda,',
#    'first-page': '804',
#    'key': '10.1063/1.113681_r3',
#    'volume': 'QE-23',
#    'year': '1987'},
#   {'author': 'Ogita,',
#    'first-page': '393',
#    'key': '10.1063/1.113681_r4',
#    'volume': '23',
#    'year': '1987'},
#   {'author': 'Murata,',
#    'first-page': '403',
#    'key': '10.1063/1.113681_r5',
#    'volume': '23',
#    'year': '1987'},
#   {'author': 'Kishino,',
#    'first-page': '343',
#    'key': '10.1063/1.113681_r6',
#    'volume': 'QE-18',
#    'year': '1982'},
#   {'author': 'Lin,',
#    'first-page': '121',
#    'key': '10.1063/1.113681_r7',
#    'volume': '46',
#    'year': '1985'},
#   {'author': 'Yoshikuni,',
#    'first-page': '820',
#    'key': '10.1063/1.113681_r8',
#    'volume': '45',
#    'year': '1984'},
#   {'author': 'Uomi,',
#    'first-page': '229',
#    'key': '10.1063/1.113681_r9',
#    'volume': 'PTL-2',
#    'year': '1990'},
#   {'author': 'Kakimoto,',
#    'first-page': '1460',
#    'key': '10.1063/1.113681_r10',
#    'volume': 'QE-26',
#    'year': '1990'},
#   {'author': 'Luo,',
#    'first-page': '307',
#    'key': '10.1063/1.113681_r11',
#    'volume': '59',
#    'year': '1991'},
#   {'author': 'Kotaki,',
#    'first-page': '990',
#    'key': '10.1063/1.113681_r12',
#    'volume': '25',
#    'year': '1989'},
#   {'author': 'Kinoshita',
#    'first-page': '2160',
#    'key': '10.1063/1.113681_r13',
#    'volume': 'QE-24',
#    'year': '1988'},
#   {'author': 'Zhang',
#    'first-page': '604',
#    'key': '10.1063/1.113681_r14',
#    'volume': 'QE-28',
#    'year': '1992'},
#   {'author': 'Vankwikelberge,',
#    'first-page': '1728',
#    'key': '10.1063/1.113681_r15',
#    'volume': 'QE-26',
#    'year': '1990'},
#   {'author': 'Yamada',
#    'first-page': '3474',
#    'key': '10.1063/1.113681_r16',
#    'volume': '26',
#    'year': '1987'},
#   {'author': 'Kuznetsov,',
#    'first-page': '1826',
#    'key': '10.1063/1.113681_r17',
#    'volume': '55',
#    'year': '1989'}],
#  'reference-count': 17,
#  'references-count': 17,
#  'relation': {'cites': []},
#  'score': 1.0,
#  'short-container-title': ['Appl. Phys. Lett.'],
#  'short-title': [],
#  'source': 'Crossref',
#  'subtitle': [],
#  'title': ['Reduction of the frequency chirp of two section distributed feedback laser by nonuniform current injection'],
#  'type': 'journal-article',
#  'volume': '66'}

# %%
print( store['10.1063/1.113684'] )
# Out:
# metadata retrieved from Crossref in 0.650 s.
# (1995) New CdTe photoconductor array detector for x‐ray applications
#    S. S. Yoo et al. - Applied Physics Letters
#    http://dx.doi.org/10.1063/1.113684

# %%
store['10.1038/nmat1352'].refs_doi
# Out:
# ['10.1016/S0169-409X(01)00239-3',
#  '10.1038/35007047',
#  '10.1038/35095031',
#  '10.1126/science.290.5496.1555',
#  '10.1023/A:1020137616302',
#  '10.1021/ja972139o',
#  '10.1063/1.113679',
#  '10.1126/science.290.5496.1540',
#  '10.1038/nmat960',
#  '10.1038/15100',
#  '10.1002/1521-4095(20020517)14:10<743::AID-ADMA743>3.0.CO;2-H',
#  '10.1103/PhysRevLett.45.1636',
#  '10.1016/S0167-7799(99)01345-1',
#  '10.1002/(SICI)1097-4636(2000)53:3<258::AID-JBM11>3.0.CO;2-O',
#  '10.1016/S0925-4005(00)00396-8',
#  '10.1038/nmat761',
#  '10.1016/S0168-583X(99)00118-4',
#  '10.1038/21619',
#  '10.1021/ac970853i',
#  '10.1016/S0169-409X(01)00241-1',
#  '10.1039/b210140h',
#  '10.1016/S0142-9612(96)00198-6',
#  '10.1016/S0378-5173(01)00976-0',
#  '10.1038/417388a',
#  '10.1016/S0169-409X(01)00246-0',
#  '10.1126/science.286.5442.1129',
#  '10.1021/bp990058l',
#  '10.1021/bc010080b',
#  '10.1038/17092',
#  '10.1126/science.281.5375.389']

# %%
len( store )
# Out:
# 6

# %%
store['10.1038/nmat1353']
# Out:
# {'DOI': '10.1038/nmat1353',
#  'ISSN': ['1476-1122', '1476-4660'],
#  'URL': 'http://dx.doi.org/10.1038/nmat1353',
#  'alternative-id': ['BFnmat1353'],
#  'author': [{'affiliation': [],
#    'family': 'Grohol',
#    'given': 'Daniel',
#    'sequence': 'first'},
#   {'affiliation': [],
#    'family': 'Matan',
#    'given': 'Kittiwit',
#    'sequence': 'additional'},
#   {'affiliation': [],
#    'family': 'Cho',
#    'given': 'Jin-Hyung',
#    'sequence': 'additional'},
#   {'affiliation': [],
#    'family': 'Lee',
#    'given': 'Seung-Hun',
#    'sequence': 'additional'},
#   {'affiliation': [],
#    'family': 'Lynn',
#    'given': 'Jeffrey W.',
#    'sequence': 'additional'},
#   {'affiliation': [],
#    'family': 'Nocera',
#    'given': 'Daniel G.',
#    'sequence': 'additional'},
#   {'affiliation': [],
#    'family': 'Lee',
#    'given': 'Young S.',
#    'sequence': 'additional'}],
#  'container-title': ['Nature Materials'],
#  'content-domain': {'crossmark-restriction': False, 'domain': []},
#  'created': {'date-parts': [[2005, 3, 27]],
#   'date-time': '2005-03-27T17:04:32Z',
#   'timestamp': 1111943072000},
#  'deposited': {'date-parts': [[2018, 2, 6]],
#   'date-time': '2018-02-06T17:39:57Z',
#   'timestamp': 1517938797000},
#  'indexed': {'date-parts': [[2018, 6, 14]],
#   'date-time': '2018-06-14T14:42:38Z',
#   'timestamp': 1528987358016},
#  'is-referenced-by-count': 149,
#  'issn-type': [{'type': 'print', 'value': '1476-1122'},
#   {'type': 'electronic', 'value': '1476-4660'}],
#  'issue': '4',
#  'issued': {'date-parts': [[2005, 3, 27]]},
#  'journal-issue': {'issue': '4',
#   'published-print': {'date-parts': [[2005, 4]]}},
#  'language': 'en',
#  'license': [{'URL': 'http://www.springer.com/tdm',
#    'content-version': 'unspecified',
#    'delay-in-days': 0,
#    'start': {'date-parts': [[2005, 3, 27]],
#     'date-time': '2005-03-27T00:00:00Z',
#     'timestamp': 1111881600000}}],
#  'link': [{'URL': 'http://www.nature.com/articles/nmat1353.pdf',
#    'content-type': 'application/pdf',
#    'content-version': 'vor',
#    'intended-application': 'text-mining'},
#   {'URL': 'http://www.nature.com/articles/nmat1353',
#    'content-type': 'text/html',
#    'content-version': 'vor',
#    'intended-application': 'text-mining'},
#   {'URL': 'http://www.nature.com/articles/nmat1353.pdf',
#    'content-type': 'application/pdf',
#    'content-version': 'vor',
#    'intended-application': 'similarity-checking'}],
#  'member': '297',
#  'original-title': [],
#  'page': '323-328',
#  'prefix': '10.1038',
#  'published-online': {'date-parts': [[2005, 3, 27]]},
#  'published-print': {'date-parts': [[2005, 4]]},
#  'publisher': 'Springer Nature',
#  'reference': [{'author': 'AP Ramirez',
#    'first-page': '423',
#    'key': 'BFnmat1353_CR1',
#    'unstructured': 'Ramirez, A. P. in Handbook on Magnetic Materials Vol. 13 (ed. Busch, K. J. H) 423–520 (Elsevier Science, Amsterdam, 2001).',
#    'volume-title': 'Handbook on Magnetic Materials',
#    'year': '2001'},
#   {'DOI': '10.1126/science.1064761',
#    'author': 'ST Bramwell',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1495',
#    'journal-title': 'Science',
#    'key': 'BFnmat1353_CR2',
#    'unstructured': 'Bramwell, S. T. & Gingras, M. J. P. Spin ice state in frustrated magnetic pyrochlore materials. Science 294, 1495–1501 (2001).',
#    'volume': '294',
#    'year': '2001'},
#   {'DOI': '10.1103/PhysRevB.45.2899',
#    'author': 'AB Harris',
#    'doi-asserted-by': 'publisher',
#    'first-page': '2899',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR3',
#    'unstructured': 'Harris, A. B., Kallin, C. & Berlinsky, A. J. Possible Néel orderings of the Kagomé antiferromagnet. Phys. Rev. B 45, 2899–2919 (1992).',
#    'volume': '45',
#    'year': '1992'},
#   {'DOI': '10.1103/PhysRevB.45.12377',
#    'author': 'S Sachdev',
#    'doi-asserted-by': 'publisher',
#    'first-page': '12377',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR4',
#    'unstructured': 'Sachdev, S. Kagomé and triangular-lattice Heisenberg antiferromagnets: ordering from quantum fluctuations and quantum-disordered ground states with unconfined bosonic spinons. Phys. Rev. B 45, 12377–12396 (1992).',
#    'volume': '45',
#    'year': '1992'},
#   {'DOI': '10.1103/PhysRevLett.68.855',
#    'author': 'JT Chalker',
#    'doi-asserted-by': 'publisher',
#    'first-page': '855',
#    'journal-title': 'Phys. Rev. Lett.',
#    'key': 'BFnmat1353_CR5',
#    'unstructured': 'Chalker, J. T., Holdsworth, P. C. W. & Shender, E. F. Hidden order in a frustrated system: properties of the Heisenberg Kagomé antiferromagnet. Phys. Rev. Lett. 68, 855–858 (1992).',
#    'volume': '68',
#    'year': '1992'},
#   {'DOI': '10.1103/PhysRevB.47.15342',
#    'author': 'I Ritchey',
#    'doi-asserted-by': 'publisher',
#    'first-page': '15342',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR6',
#    'unstructured': 'Ritchey, I., Chandra, P. & Coleman, P. Spin folding in the two-dimensional Heisenberg Kagomé antiferromagnet. Phys. Rev. B 47, 15342–15345 (1993).',
#    'volume': '47',
#    'year': '1993'},
#   {'DOI': '10.1103/PhysRevB.61.12181',
#    'author': 'T Inami',
#    'doi-asserted-by': 'publisher',
#    'first-page': '12181',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR7',
#    'unstructured': 'Inami, T., Nishiyama, M., Maegawa, S. & Oka, Y. Magnetic structure of the Kagomé lattice antiferromagnet potassium jarosite KFe3(OH)6(SO4)2 . Phys. Rev. B 61, 12181–12186 (2000).',
#    'volume': '61',
#    'year': '2000'},
#   {'DOI': '10.1103/PhysRevB.63.064430',
#    'author': 'AS Wills',
#    'doi-asserted-by': 'publisher',
#    'first-page': '064430',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR8',
#    'unstructured': 'Wills, A. S. Long-range ordering and representational analysis of the jarosites. Phys. Rev. B 63, 064430 (2001).',
#    'volume': '63',
#    'year': '2001'},
#   {'DOI': '10.1103/PhysRevB.39.11413',
#    'author': 'XG Wen',
#    'doi-asserted-by': 'publisher',
#    'first-page': '11413',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR9',
#    'unstructured': 'Wen, X. G., Wilczek, F. & Zee, A. Chiral spin states and superconductivity. Phys. Rev. B 39, 11413–11423 (1989).',
#    'volume': '39',
#    'year': '1989'},
#   {'DOI': '10.1103/PhysRevB.62.R6065',
#    'author': 'K Ohgushi',
#    'doi-asserted-by': 'publisher',
#    'first-page': 'R6065',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR10',
#    'unstructured': 'Ohgushi, K., Murakami, S. & Nagaosa, N. Spin anisotropy and quantum Hall effect in the Kagomé lattice: chiral spin state based on a ferromagnet. Phys. Rev. B 62, R6065–R6068 (2000).',
#    'volume': '62',
#    'year': '2000'},
#   {'DOI': '10.1126/science.1058161',
#    'author': 'Y Taguchi',
#    'doi-asserted-by': 'publisher',
#    'first-page': '2573',
#    'journal-title': 'Science',
#    'key': 'BFnmat1353_CR11',
#    'unstructured': 'Taguchi, Y., Oohara, Y., Yoshizawa, H., Nagaosa, N. & Tokura, Y. Spin chirality, Berry phase and anomalous Hall effect in a frustrated ferromagnet. Science 291, 2573–2576 (2001).',
#    'volume': '291',
#    'year': '2001'},
#   {'DOI': '10.1103/PhysRevB.61.6156',
#    'author': 'AS Wills',
#    'doi-asserted-by': 'publisher',
#    'first-page': '6156',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR12',
#    'unstructured': 'Wills, A. S., Harrison, A., Ritter, C. & Smith, R. I. Magnetic properties of pure and diamagnetically doped jarosites: model Kagome antiferromagnets with variable coverage of the magnetic lattice. Phys. Rev. B 61, 6156–6169 (2000).',
#    'volume': '61',
#    'year': '2000'},
#   {'DOI': '10.1002/chem.200306074',
#    'author': 'DG Nocera',
#    'doi-asserted-by': 'publisher',
#    'first-page': '3850',
#    'journal-title': 'Chem. Eur. J.',
#    'key': 'BFnmat1353_CR13',
#    'unstructured': 'Nocera, D. G., Bartlett, B. M., Grohol, D., Papoutsakis, D. & Shores, M. P. Spin frustration in 2D Kagomé lattices: a problem for inorganic synthetic chemistry. Chem. Eur. J. 10, 3850–3859 (2004).',
#    'volume': '10',
#    'year': '2004'},
#   {'key': 'BFnmat1353_CR14',
#    'unstructured': 'Kawamura, H. in Proc. Workshop on Low-Dimensional Quantum Antiferromagnets (Fukuoka, 2001 11); cond-mat/0202109.'},
#   {'DOI': '10.1103/PhysRevB.64.184408',
#    'author': 'P Calabrese',
#    'doi-asserted-by': 'publisher',
#    'first-page': '184408',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR15',
#    'unstructured': 'Calabrese, P. & Parruccini, P. Critical behavior of two-dimensional frustrated spin models with noncollinear order. Phys. Rev. B 64, 184408 (2001).',
#    'volume': '64',
#    'year': '2001'},
#   {'DOI': '10.1103/PhysRevB.39.586',
#    'author': 'TE Mason',
#    'doi-asserted-by': 'publisher',
#    'first-page': '586',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR16',
#    'unstructured': 'Mason, T. E., Gaulin, B. D. & Collins, M. F. Neutron scattering measurements of critical exponents in CsMnBr3: a Z2 × S1 antiferromagnet. Phys. Rev. B 39, 586–590 (1989).',
#    'volume': '39',
#    'year': '1989'},
#   {'DOI': '10.1103/PhysRevB.64.100402',
#    'author': 'VP Plakhty',
#    'doi-asserted-by': 'publisher',
#    'first-page': '100402',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR17',
#    'unstructured': 'Plakhty, V. P. et al. Chiral criticality in helimagnet Ho studied by polarized neutron scattering. Phys. Rev. B 64, 100402 (2001).',
#    'volume': '64',
#    'year': '2001'},
#   {'DOI': '10.1103/PhysRevB.67.064401',
#    'author': 'D Grohol',
#    'doi-asserted-by': 'publisher',
#    'first-page': '064401',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR18',
#    'unstructured': 'Grohol, D., Nocera, D. G. & Papoutsakis, D. Magnetism of pure iron jarosite. Phys. Rev. B 67, 064401 (2003).',
#    'volume': '67',
#    'year': '2003'},
#   {'DOI': '10.1103/PhysRevB.66.014422',
#    'author': 'M Elhajal',
#    'doi-asserted-by': 'publisher',
#    'first-page': '014422',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR19',
#    'unstructured': 'Elhajal, M., Canals, B. & Lacroix, C. Symmetry breaking due to Dzyaloshinsky–Moriya interactions in the Kagomé lattice. Phys. Rev. B 66, 014422 (2002).',
#    'volume': '66',
#    'year': '2002'},
#   {'DOI': '10.1103/PhysRev.120.91',
#    'author': 'T Moriya',
#    'doi-asserted-by': 'publisher',
#    'first-page': '91',
#    'journal-title': 'Phys. Rev.',
#    'key': 'BFnmat1353_CR20',
#    'unstructured': 'Moriya, T. Anisotropic superexchange interaction and weak ferromagnetism. Phys. Rev. 120, 91–98 (1960).',
#    'volume': '120',
#    'year': '1960'},
#   {'DOI': '10.1007/s002570050158',
#    'author': 'BO Wells',
#    'doi-asserted-by': 'publisher',
#    'first-page': '535',
#    'journal-title': 'Z. Phys. B',
#    'key': 'BFnmat1353_CR21',
#    'unstructured': 'Wells, B. O. et al. Intercalation and staging behavior in super-oxygenated La2CuO4+d . Z. Phys. B 100, 535–545 (1996).',
#    'volume': '100',
#    'year': '1996'},
#   {'DOI': '10.1103/PhysRevB.38.905',
#    'author': 'T Thio',
#    'doi-asserted-by': 'publisher',
#    'first-page': '905',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR22',
#    'unstructured': 'Thio, T. et al. Antisymmetric exchange and its influence on the magnetic structure and conductivity of La2CuO4 . Phys. Rev. B 38, 905–908 (1988).',
#    'volume': '38',
#    'year': '1988'},
#   {'DOI': '10.1103/PhysRevB.48.9539',
#    'author': 'JN Reimers',
#    'doi-asserted-by': 'publisher',
#    'first-page': '9539',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR23',
#    'unstructured': 'Reimers, J. N. & Berlinsky, A. J. Order by disorder in the classical Heisenberg Kagomé antiferromagnet. Phys. Rev. B 48, 9539–9554 (1993).',
#    'volume': '48',
#    'year': '1993'},
#   {'DOI': '10.1103/PhysRevB.67.224435',
#    'author': 'M Nishiyama',
#    'doi-asserted-by': 'publisher',
#    'first-page': '224435',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR24',
#    'unstructured': 'Nishiyama, M., Maegawa, S., Inami, T., & Oka, Y. Magnetic ordering and spin dynamics in potassium jarosite: a Heisenberg Kagomé lattice antiferromagnet. Phys. Rev. B 67, 224435 (2003).',
#    'volume': '67',
#    'year': '2003'},
#   {'DOI': '10.1103/PhysRevLett.69.832',
#    'author': 'A Chubukov',
#    'doi-asserted-by': 'publisher',
#    'first-page': '832',
#    'journal-title': 'Phys. Rev. Lett.',
#    'key': 'BFnmat1353_CR25',
#    'unstructured': 'Chubukov, A. Order from disorder in a Kagomé antiferromagnet. Phys. Rev. Lett. 69, 832–835 (1992).',
#    'volume': '69',
#    'year': '1992'},
#   {'DOI': '10.1103/PhysRevB.56.8091',
#    'author': 'SH Lee',
#    'doi-asserted-by': 'publisher',
#    'first-page': '8091',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR26',
#    'unstructured': 'Lee, S. H. et al. Less than 50% sublattice polarization in an insulating S=3/2 Kagomé antiferromagnet at T ∼ 0. Phys. Rev. B 56, 8091–8097 (1997).',
#    'volume': '56',
#    'year': '1997'},
#   {'DOI': '10.1103/PhysRevB.52.10239',
#    'author': 'T Yildirim',
#    'doi-asserted-by': 'publisher',
#    'first-page': '10239',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR27',
#    'unstructured': 'Yildirim, T., Harris, A. B., Aharony, A. & Entin-Wohlman, O. Anisotropic spin Hamiltonian due to spin-orbit and coulomb exchange interactions. Phys. Rev. B 52, 10239–10267 (1995).',
#    'volume': '52',
#    'year': '1995'},
#   {'DOI': '10.1103/PhysRevLett.17.1133',
#    'author': 'N Mermin',
#    'doi-asserted-by': 'publisher',
#    'first-page': '1133',
#    'journal-title': 'Phys. Rev. Lett.',
#    'key': 'BFnmat1353_CR28',
#    'unstructured': 'Mermin, N. & Wagner, H. Absence of ferromagnetism or antiferromagnetism in one- or two-dimensional isotropic Heisenberg models. Phys. Rev. Lett. 22, 1133–1136 (1966).',
#    'volume': '22',
#    'year': '1966'},
#   {'DOI': '10.1103/PhysRevB.48.965',
#    'author': 'J von Delft',
#    'doi-asserted-by': 'publisher',
#    'first-page': '965',
#    'journal-title': 'Phys. Rev. B',
#    'key': 'BFnmat1353_CR29',
#    'unstructured': 'von Delft, J. & Henley, C. L. Spin tunneling in the Kagomé antiferromagnet. Phys. Rev. B 48, 965–984 (1993).',
#    'volume': '48',
#    'year': '1993'}],
#  'reference-count': 29,
#  'references-count': 29,
#  'relation': {'cites': []},
#  'score': 1.0,
#  'short-container-title': ['Nature Mater'],
#  'short-title': [],
#  'source': 'Crossref',
#  'subtitle': [],
#  'title': ['Spin chirality on a two-dimensional frustrated lattice'],
#  'type': 'journal-article',
#  'volume': '4'}
