# %% [markdown]
# # authors statistics

# %%
import pandas as pd
from beakerx import *

# %%
import bibigraph as big

# %%
# %load_ext autoreload
# %autoreload 2

# %%
biblio = big.Bibliography()

datafile = 'data/citing_Nye1953_journals.bib'
biblio.load( datafile )
# Out:
# 930 articles added

# %%
biblio.articles[4]
# Out:
# A unified framework for polycr... (2018) International Journal of Plasticity

# %%
sorted( [ (auth, len(keys)) for auth, keys in biblio.authors.items()], key=lambda x:x[1], reverse=True )
# Out:
# [('Huang, Y.', 45),
#  ('Hwang, K.C.', 31),
#  ('Wilkinson, A.J.', 28),
#  ('Fressengeas, C.', 26),
#  ('Taupin, V.', 22),
#  ('Britton, T.B.', 18),
#  ('Raabe, D.', 18),
#  ('Le, K.C.', 17),
#  ('Adams, B.L.', 15),
#  ('Field, D.P.', 15),
#  ('Gao, H.', 14),
#  ('Acharya, A.', 14),
#  ('Ortiz, M.', 14),
#  ('Gurtin, M.E.', 13),
#  ('Nazari, A.', 12),
#  ('Dunne, F.P.E.', 12),
#  ('Berbenni, S.', 12),
#  ('Xiang, Y.', 12),
#  ('Forest, S.', 12),
#  ('Fullwood, D.T.', 11),
#  ('Needleman, A.', 11),
#  ('Roters, F.', 11),
#  ('Nix, W.D.', 11),
#  ('Geers, M.G.D.', 11),
#  ('McDowell, D.L.', 10),
#  ('Bammann, D.J.', 10),
#  ('Jiang, J.', 10),
#  ('Svendsen, B.', 9),
#  ('Capolungo, L.', 9),
#  ('Zbib, H.M.', 9),
#  ('Beaudoin, A.J.', 9),
#  ('Voyiadjis, G.Z.', 9),
#  ('Tamura, N.', 9),
#  ('Sandfeld, S.', 9),
#  ('Bardella, L.', 9),
#  ('Kysar, J.W.', 9),
#  ('Qu, S.', 8),
#  ('Pharr, G.M.', 8),
#  ('Böhlke, T.', 8),
#  ('Ma, A.', 8),
#  ('Clayton, J.D.', 8),
#  ('Neff, P.', 8),
#  ('Liu, W.', 7),
#  ('Beausir, B.', 7),
#  ('Miehe, C.', 7),
#  ('Montagnat, M.', 7),
#  ('Li, M.', 7),
#  ('Wulfinghoff, S.', 7),
#  ('Van Der Giessen, E.', 7),
#  ('Zhu, Y.', 7),
#  ('Busso, E.P.', 6),
#  ('Ice, G.E.', 6),
#  ('Lazar, M.', 6),
#  ('Larson, B.C.', 6),
#  ('Swaddiwudhipong, S.', 6),
#  ('Brekelmans, W.A.M.', 6),
#  ('Zaiser, M.', 6),
#  ('Abu Al-Rub, R.K.', 6),
#  ('Zhang, F.', 6),
#  ('Cermelli, P.', 6),
#  ('Pantleon, W.', 6),
#  ('Richeton, T.', 6),
#  ('Wu, P.D.', 6),
#  ('Zaefferer, S.', 6),
#  ('Fleck, N.A.', 6),
#  ('Horstemeyer, M.F.', 5),
#  ('Ghosh, S.', 5),
#  ('Hua, J.', 5),
#  ('Barabash, R.I.', 5),
#  ('Chevy, J.', 5),
#  ('Deshpande, V.S.', 5),
#  ('Bargmann, S.', 5),
#  ('Van der Giessen, E.', 5),
#  ('Gumbsch, P.', 5),
#  ('Eisenlohr, P.', 5),
#  ('Tischler, J.Z.', 5),
#  ('Han, C.-S.', 5),
#  ('Hutchinson, J.W.', 5),
#  ('Budiman, A.S.', 5),
#  ('Demir, E.', 5),
#  ('Hochrainer, T.', 5),
#  ('Duval, P.', 5),
#  ('Engel, U.', 5),
#  ('Li, Z.', 5),
#  ('Yassar, R.S.', 5),
#  ('Chen, J.Y.', 5),
#  ('Ariza, M.P.', 5),
#  ('Sedláček, R.', 5),
#  ('Hwang, K.-C.', 5),
#  ('Hartley, C.S.', 5),
#  ('Kupferman, R.', 5),
#  ('Ruggles, T.J.', 5),
#  ('Sprackling, M.T.', 4),
#  ('Roy, A.', 4),
#  ('Bassani, J.L.', 4),
#  ('Tho, K.K.', 4),
#  ('Van Goethem, N.', 4),
#  ('Yang, J.', 4),
#  ('Harrington, T.', 4),
#  ('Puri, S.', 4),
#  ('Kacher, J.', 4),
#  ('Ekh, M.', 4),
#  ('Mesarovic, S.Dj.', 4),
#  ('Katanaev, M.O.', 4),
#  ('Garroni, A.', 4),
#  ('Kléman, M.', 4),
#  ('Taheri, M.L.', 4),
#  ('Zhu, X.', 4),
#  ('Kleman, M.', 4),
#  ('Hartmaier, A.', 4),
#  ('Ohno, N.', 4),
#  ('Gudmundson, P.', 4),
#  ('Kröner, E.', 4),
#  ('Qiu, X.', 4),
#  ('Liu, Z.S.', 4),
#  ('Mayeur, J.R.', 4),
#  ('Dunstan, D.J.', 4),
#  ('Steinmann, P.', 4),
#  ('Guruprasad, P.J.', 4),
#  ('Maor, C.', 4),
#  ('Wang, Y.', 4),
#  ('El-Azab, A.', 4),
#  ('Van Swygenhoven, H.', 4),
#  ('Anand, L.', 4),
#  ('Lyu, H.', 4),
#  ('Cordero, N.M.', 4),
#  ('Shi, M.X.', 4),
#  ('Dahlberg, C.F.O.', 4),
#  ('Kunz, M.', 4),
#  ('Mahesh, S.', 4),
#  ('He, D.', 4),
#  ('Guo, Y.', 4),
#  ('Mishra, R.K.', 4),
#  ('Zhu, C.', 4),
#  ('Saito, Y.', 4),
#  ('Sethna, J.P.', 4),
#  ('Rollett, A.D.', 4),
#  ('Dimiduk, D.M.', 4),
#  ('Faghihi, D.', 4),
#  ('Mishin, Y.', 4),
#  ('Geiger, M.', 4),
#  ('Zhang, T.', 4),
#  ('Sembiring, P.', 4),
#  ('Lebyodkin, M.', 4),
#  ('Koslowski, M.', 4),
#  ('Jiang, H.', 4),
#  ('Liu, C.', 4),
#  ('Benzerga, A.A.', 4),
#  ('Karamched, P.S.', 4),
#  ('Michler, J.', 4),
#  ('Grilli, N.', 3),
#  ('Garikipati, K.', 3),
#  ('Leff, A.C.', 3),
#  ('Oh, K.H.', 3),
#  ('Regueiro, R.A.', 3),
#  ('Seefeldt, M.', 3),
#  ('Evers, L.P.', 3),
#  ('Li, S.', 3),
#  ('Pagan, D.C.', 3),
#  ('Rey, C.', 3),
#  ('Feng, X.', 3),
#  ('Oztop, M.S.', 3),
#  ('Upadhyay, M.', 3),
#  ('Joshi, S.P.', 3),
#  ('Aifantis, E.C.', 3),
#  ('Martin, D.C.', 3),
#  ('Weng, G.J.', 3),
#  ('Lee, S.', 3),
#  ('Arsenlis, A.', 3),
#  ('Wallis, D.', 3),
#  ('Florando, J.N.', 3),
#  ('Lassila, D.H.', 3),
#  ('Gil Sevillano, J.', 3),
#  ('Reddy, B.D.', 3),
#  ('Vehoff, H.', 3),
#  ('Huang, M.', 3),
#  ('Giacomini, A.', 3),
#  ('Zhang, C.', 3),
#  ('Shizawa, K.', 3),
#  ('Vattré, A.', 3),
#  ('Hunter, A.', 3),
#  ('Reed, R.C.', 3),
#  ('Aghababaei, R.', 3),
#  ('Lookman, T.', 3),
#  ('Chung, P.W.', 3),
#  ('Inal, K.', 3),
#  ('Gröger, R.', 3),
#  ('Hofmann, F.', 3),
#  ('Birosca, S.', 3),
#  ('Homer, E.R.', 3),
#  ('Chen, K.', 3),
#  ('Suwas, S.', 3),
#  ('Maeder, X.', 3),
#  ('Irastorza-Landa, A.', 3),
#  ('Gan, Y.X.', 3),
#  ('Teisseyre, R.', 3),
#  ('Gupta, A.', 3),
#  ('Dłuzewski, P.', 3),
#  ('Phillips, A.', 3),
#  ('Okumura, D.', 3),
#  ('Dimitrakopulos, G.P.', 3),
#  ('Korsunsky, A.M.', 3),
#  ('Gupta, V.K.', 3),
#  ('Anahid, M.', 3),
#  ('Greer, J.R.', 3),
#  ('Ponsiglione, M.', 3),
#  ('Qin, J.', 3),
#  ('Clegg, W.J.', 3),
#  ('Huang, J.', 3),
#  ('Beyerlein, I.J.', 3),
#  ('Ashby, M.F.', 3),
#  ('Aldakheel, F.', 3),
#  ('Xiao, J.', 3),
#  ('Vecchio, K.S.', 3),
#  ('Winther, G.', 3),
#  ('Peerlings, R.H.J.', 3),
#  ('Yefimov, S.', 3),
#  ('Wang, H.', 3),
#  ('Kuribayashi, K.', 3),
#  ('Nagahama, H.', 3),
#  ('Ast, J.', 3),
#  ('Hansen, N.', 3),
#  ('Kim, H.S.', 3),
#  ('Willis, J.R.', 3),
#  ('Uchic, M.D.', 3),
#  ('Hansen, L.N.', 3),
#  ('Varadhan, S.', 3),
#  ('Xue, Z.', 3),
#  ('Beaudoin, A.', 3),
#  ('Po, G.', 3),
#  ('Tjahjanto, D.D.', 3),
#  ('Siegmund, T.', 3),
#  ('Kucheyev, S.O.', 3),
#  ('Kratochvíl, J.', 3),
#  ('Wagoner, R.H.', 3),
#  ('Miller, M.P.', 3),
#  ('Kochmann, D.M.', 3),
#  ('Liu, D.', 3),
#  ('Lebensohn, R.A.', 3),
#  ('Sato, E.', 3),
#  ('Saada, G.', 3),
#  ('Zhang, L.', 3),
#  ('Berveiller, M.', 3),
#  ('Parks, D.M.', 3),
#  ('Ruimi, A.', 3),
#  ('Bayerschen, E.', 3),
#  ('Limkumnerd, S.', 3),
#  ('Leen, S.B.', 3),
#  ('Li, Q.', 3),
#  ('Tóth, L.S.', 3),
#  ('Spolenak, R.', 3),
#  ('Panteghini, A.', 3),
#  ('Patel, J.R.', 3),
#  ('Lu, C.', 3),
#  ('Misra, A.', 3),
#  ('Madeo, A.', 3),
#  ('Agnew, S.R.', 3),
#  ('Diehl, A.', 3),
#  ('Collins, D.M.', 3),
#  ('Lele, S.P.', 3),
#  ('Huang, X.', 3),
#  ('Swadener, J.G.', 3),
#  ('Repetto, E.A.', 2),
#  ('Wang, X.', 2),
#  ('Hardin, T.J.', 2),
#  ('Yun, G.', 2),
#  ('Baskaran, R.', 2),
#  ('Osterbrink, F.', 2),
#  ('Berdichevsky, V.L.', 2),
#  ('Kübel, C.', 2),
#  ('Mishra, R.S.', 2),
#  ('Tsui, T.Y.', 2),
#  ('Schulz, K.', 2),
#  ('Basinger, J.', 2),
#  ('Zhang, H.', 2),
#  ('Fedelich, B.', 2),
#  ('Basaran, C.', 2),
#  ('Tarleton, E.', 2),
#  ('Golubenko, A.A.', 2),
#  ('Roessiger, J.', 2),
#  ('Liu, M.', 2),
#  ('Bouaziz, O.', 2),
#  ('Pang, J.W.L.', 2),
#  ('Van Petegem, S.', 2),
#  ('Nyilas, R.D.', 2),
#  ('Allain-Bonasso, N.', 2),
#  ('Sumino, K.', 2),
#  ('Gupta, S.', 2),
#  ('Vilalta-Clemente, A.', 2),
#  ('Guo, T.F.', 2),
#  ('Zhang, Z.F.', 2),
#  ('Armstrong, D.E.J.', 2),
#  ('Motz, C.', 2),
#  ('Schoeck, G.', 2),
#  ('Littlewood, P.D.', 2),
#  ('Appolaire, B.', 2),
#  ('Klusemann, B.', 2),
#  ('Suquet, P.', 2),
#  ('Malygin, G.A.', 2),
#  ('Piazolo, S.', 2),
#  ('Parthasarathy, T.A.', 2),
#  ('Runesson, K.', 2),
#  ('Sun, S.', 2),
#  ('Bons, P.D.', 2),
#  ('Maruszewski, B.', 2),
#  ('Szabó, P.J.', 2),
#  ('Borg, U.', 2),
#  ('Zubov, L.M.', 2),
#  ('Srolovitz, D.J.', 2),
#  ('Pippan, R.', 2),
#  ('Zikry, M.A.', 2),
#  ('Christian, J.W.', 2),
#  ('Bažant, Z.P.', 2),
#  ('Esquivel, A.L.', 2),
#  ('Ertürk, I.', 2),
#  ('Wang, Z.', 2),
#  ('Ashton, P.J.', 2),
#  ('Bieler, T.', 2),
#  ('Hu, X.', 2),
#  ('Blum, W.', 2),
#  ('Misra, R.D.K.', 2),
#  ('Sehitoglu, H.', 2),
#  ('Bastie, P.', 2),
#  ('Gao, Y.', 2),
#  ('Dong, X.', 2),
#  ('Jothi, S.', 2),
#  ('Groma, I.', 2),
#  ('Marian, J.', 2),
#  ('Li, J.', 2),
#  ('Harte, A.M.', 2),
#  ('Dub, S.N.', 2),
#  ('Ahn, D.-H.', 2),
#  ('Benjamin Britton, T.', 2),
#  ('Kontis, P.', 2),
#  ('Barabash, R.', 2),
#  ('Wlerzbanowski, K.', 2),
#  ('Brahme, A.', 2),
#  ('Liu, B.', 2),
#  ('Münch, I.', 2),
#  ('Shi, Z.', 2),
#  ('van Dommelen, J.A.W.', 2),
#  ('Grymer, M.', 2),
#  ('Mauthe, S.', 2),
#  ('Grennerat, F.', 2),
#  ('Lee, G.', 2),
#  ('Papanikolaou, S.', 2),
#  ('George, E.P.', 2),
#  ('Segurado, J.', 2),
#  ('Kiwanuka, R.', 2),
#  ('Sarac, A.', 2),
#  ('Roos, A.', 2),
#  ('Levkovitch, V.', 2),
#  ('Choi, W.', 2),
#  ('De Luca, L.', 2),
#  ('Stucker, B.E.', 2),
#  ('Al-Rub, R.K.A.', 2),
#  ('Cordier, P.', 2),
#  ('Fivel, M.', 2),
#  ('Lozano-Perez, S.', 2),
#  ('Gbemou, K.', 2),
#  ('Dickel, D.', 2),
#  ('Bittencourt, E.', 2),
#  ('Wang, S.', 2),
#  ('Yasmeen, T.', 2),
#  ('Burek, M.J.', 2),
#  ('Kirchlechner, C.', 2),
#  ('Monchiet, V.', 2),
#  ('Nakada, N.', 2),
#  ('Zhao, Z.', 2),
#  ('Wenk, H.-R.', 2),
#  ('Sellers, S.', 2),
#  ('Nicola, L.', 2),
#  ('Alicandro, R.', 2),
#  ('Toth, L.S.', 2),
#  ('Fan, D.', 2),
#  ('Rampton, T.M.', 2),
#  ('Weinberger, C.R.', 2),
#  ('Cherkaoui, M.', 2),
#  ('Tran, T.M.', 2),
#  ('Marin, E.B.', 2),
#  ('Tsuchiyama, T.', 2),
#  ('Griera, A.', 2),
#  ('Jun, T.-S.', 2),
#  ('Meyssonnier, J.', 2),
#  ('Song, J.', 2),
#  ('Hielscher, R.', 2),
#  ('Stupkiewicz, S.', 2),
#  ('Monavari, M.', 2),
#  ('Kumar, M.', 2),
#  ('Meaden, G.', 2),
#  ('Sun, X.-Y.', 2),
#  ('Goldsby, D.L.', 2),
#  ('Lesar, R.', 2),
#  ('Landon, C.', 2),
#  ('Petryk, H.', 2),
#  ('Di Gioacchino, F.', 2),
#  ('Livescu, V.', 2),
#  ('Wright, S.I.', 2),
#  ('Elkhodary, K.I.', 2),
#  ('Khosravani, A.', 2),
#  ('Kružík, M.', 2),
#  ('Martínez-Esnaola, J.M.', 2),
#  ('Chen, X.', 2),
#  ('Komninou, Ph.', 2),
#  ('Djaka, K.S.', 2),
#  ('Samajdar, I.', 2),
#  ('Mojtahed Najafi, S.M.', 2),
#  ('King, W.E.', 2),
#  ('Zhang, W.', 2),
#  ('Bonnet, R.', 2),
#  ('Abbey, B.', 2),
#  ('Wheeler, J.', 2),
#  ('Gomez, J.', 2),
#  ('Zhang, Y.', 2),
#  ('Guo, Z.', 2),
#  ('Wei, Y.', 2),
#  ('Yang, W.', 2),
#  ('Liang, H.', 2),
#  ('Chen, Y.S.', 2),
#  ('Chen, Y.', 2),
#  ('Kamaya, M.', 2),
#  ('Kuroda, M.', 2),
#  ('Ungár, T.', 2),
#  ('Niu, X.', 2),
#  ('Calcagnotto, M.', 2),
#  ('Abdolvand, H.', 2),
#  ('Weiss, J.', 2),
#  ('Conti, S.', 2),
#  ('Akarapu, S.', 2),
#  ('Ghasemi Banadkouki, S.S.', 2),
#  ('Tavareh, S.', 2),
#  ('Nguyen, B.D.', 2),
#  ('Öztop, M.S.', 2),
#  ('Bernacki, M.', 2),
#  ('Faruk, A.N.M.', 2),
#  ('Prakash, A.', 2),
#  ('Lin, W.N.', 2),
#  ('Thom, C.A.', 2),
#  ('Gray, G.T., III', 2),
#  ('Han, H.N.', 2),
#  ('Wang, L.', 2),
#  ('Durst, K.', 2),
#  ('Trimby, P.', 2),
#  ('Hirschberger, C.B.', 2),
#  ('Hamza, A.V.', 2),
#  ('Paufler, P.', 2),
#  ('Menzel, A.', 2),
#  ('Estrin, Y.', 2),
#  ('Niezgoda, S.R.', 2),
#  ('Barabash, O.M.', 2),
#  ('Gardner, C.J.', 2),
#  ('Trivedi, P.B.', 2),
#  ('Hirth, J.P.', 2),
#  ('Devincre, B.', 2),
#  ('Ponge, D.', 2),
#  ('Saxena, A.', 2),
#  ('Samal, M.K.', 2),
#  ('Anguige, K.', 2),
#  ('Wagner, F.', 2),
#  ('Wang, C.', 2),
#  ('Göken, M.', 2),
#  ('Neily, S.', 2),
#  ('Dupret, F.', 2),
#  ('Song, X.', 2),
#  ('Van Houtte, P.', 2),
#  ('Ohashi, T.', 2),
#  ('Chen, S.', 2),
#  ('Hughes, D.A.', 2),
#  ('Ghoniem, N.', 2),
#  ('Karakostas, Th.', 2),
#  ('Fandeur, O.', 2),
#  ('Dingley, D.J.', 2),
#  ('Golovin, Y.I.', 2),
#  ('Philip, A.', 2),
#  ("O'Dowd, N.P.", 2),
#  ('Chauve, T.', 2),
#  ('Shollock, B.A.', 2),
#  ('Mohandesi, J.A.', 2),
#  ('Miles, M.P.', 2),
#  ('Fullwood, D.', 2),
#  ('Takaki, S.', 2),
#  ('Magid, K.R.', 2),
#  ('Niordson, C.F.', 2),
#  ('Meissonnier, F.T.', 2),
#  ('Ghiba, I.-D.', 2),
#  ('Lillo, T.M.', 2),
#  ('Brown, S.G.R.', 2),
#  ('Zhang, Z.', 2),
#  ('Pugno, N.M.', 2),
#  ('White, K.W.', 1),
#  ('Shuvarin, I.A.', 1),
#  ('Cho, J.-S.', 1),
#  ('Saha, R.', 1),
#  ('Valdenaire, P.-L.', 1),
#  ('Omiya, M.', 1),
#  ('Wright, J.P.', 1),
#  ('Ding, H.', 1),
#  ('Masoumi, M.', 1),
#  ('Kondo, R.', 1),
#  ('Uchic, M.', 1),
#  ('Schlenker, M.', 1),
#  ('Wu, R.', 1),
#  ('Nong, Z.-S.', 1),
#  ('Cuo, T.F.', 1),
#  ('AbuOmar, O.', 1),
#  ('Tyapunina, N.A.', 1),
#  ('Bertin, N.', 1),
#  ('Owen, D.R.', 1),
#  ('Zilahi, G.', 1),
#  ('Merriman, C.C.', 1),
#  ('Ji, J.', 1),
#  ('Javili, A.', 1),
#  ('Onuki, Y.', 1),
#  ('Ben Saada, M.', 1),
#  ('Kou, H.', 1),
#  ('Kleiner, M.', 1),
#  ('Lebensohn, R.', 1),
#  ('Schultz, L.', 1),
#  ('Belassel, M.', 1),
#  ('Evans, L.', 1),
#  ('Feng, G.', 1),
#  ('Bisht, A.', 1),
#  ('Hoagland, R.G.', 1),
#  ('Reddy, S.M.', 1),
#  ('Viatkina, E.M.', 1),
#  ('Kumar, G.R.', 1),
#  ('Dong, J.', 1),
#  ('Ramazani, A.', 1),
#  ('Gu, C.', 1),
#  ('Gruber, P.A.', 1),
#  ('Clement, A.', 1),
#  ('Moser, B.', 1),
#  ('Poh, L.H.', 1),
#  ('Steinberger, D.', 1),
#  ('Pinna, C.', 1),
#  ('Hu, K.X.', 1),
#  ('Myers, M.T.', 1),
#  ('Williams, W.S.', 1),
#  ('Berkov, D.V.', 1),
#  ('Zhang, D.', 1),
#  ('Ebobisse, F.', 1),
#  ('Kobas, M.', 1),
#  ('Steigmann, D.J.', 1),
#  ('Ye, Z.', 1),
#  ('Brodsky, E.E.', 1),
#  ('Srinivasan, K.', 1),
#  ('Matias, J.', 1),
#  ('Godefroy, S.', 1),
#  ('Yin, Z.', 1),
#  ('Aydelotte, B.', 1),
#  ('Tomé, C.N.', 1),
#  ('Zhao, H.', 1),
#  ('Winwood, S.', 1),
#  ('Pipard, J.-M.', 1),
#  ('Bîrsan, M.', 1),
#  ('Finel, A.', 1),
#  ('Liang, J.', 1),
#  ('Tian, Y.Z.', 1),
#  ('Zhang, B.', 1),
#  ('Salman, O.U.', 1),
#  ('Walter, M.', 1),
#  ('Shet, C.', 1),
#  ('Tsivinsky, S.V.', 1),
#  ('Cho, Y.', 1),
#  ('Baek, S.M.', 1),
#  ('Chen, Ch.', 1),
#  ('Haussy, B.', 1),
#  ('Xu, D.S.', 1),
#  ('Petrov, R.', 1),
#  ('Ventura, P.', 1),
#  ('Peraudeau, B.', 1),
#  ('Hu, A.', 1),
#  ('Chandra, A.', 1),
#  ('Ferreira, R.F.', 1),
#  ('Salvat Cantó, J.', 1),
#  ('Ammar, K.', 1),
#  ('Zimmerman, J.A.', 1),
#  ('Reuber, C.', 1),
#  ('Browning, N.D.', 1),
#  ('Gong, Y.', 1),
#  ('Duflou, J.', 1),
#  ('De Hosson, J.T.M.', 1),
#  ('Zhang, M.', 1),
#  ('Pigeon, F.', 1),
#  ('Jackson, B.E.', 1),
#  ('Basavaraj, V.', 1),
#  ('Grolimund, D.', 1),
#  ('Nicaise, N.', 1),
#  ('Colombier, J.-P.', 1),
#  ('Straughan, B.W.', 1),
#  ('Suiker, A.S.J.', 1),
#  ('Adam, K.', 1),
#  ('Espinosa, H.D.', 1),
#  ('Dashwood, R.', 1),
#  ('Ningyun, W.', 1),
#  ('Chakrabarty, R.', 1),
#  ('Steidl, G.', 1),
#  ('Hong, S.S.', 1),
#  ('McMeeking, R.M.', 1),
#  ('Suresh, K.G.', 1),
#  ('Gurao, N.P.', 1),
#  ('Pang, M.', 1),
#  ('Sweeney, C.A.', 1),
#  ('Chapman, S.J.', 1),
#  ('Günther, C.', 1),
#  ('Gueninchault, N.', 1),
#  ('Balluffi, R.W.', 1),
#  ('Jonsson, A.', 1),
#  ('Thawinan, E.', 1),
#  ('Grinfeld, M.A.', 1),
#  ('Woodcock, T.G.', 1),
#  ('Head, A.K.', 1),
#  ('Jones, M.E.', 1),
#  ('Kehagias, Th.', 1),
#  ('Suzuki, K.', 1),
#  ('Nakata, H.', 1),
#  ('Remmers, J.J.C.', 1),
#  ('Derezin, S.V.', 1),
#  ('Song, H.', 1),
#  ('Meisnar, M.', 1),
#  ('Weber, L.', 1),
#  ('Sebald, T.', 1),
#  ('Ma, Q.', 1),
#  ('Sahoo, D.', 1),
#  ('Shao, C.W.', 1),
#  ('Müller, S.', 1),
#  ('Robertson, C.', 1),
#  ('Flinn, J.E.', 1),
#  ('Sangal, S.', 1),
#  ('Diaco, M.', 1),
#  ('Zabaras, N.', 1),
#  ('Farahmand, H.', 1),
#  ('Wells, M.', 1),
#  ('Wriggers, P.', 1),
#  ('Chelladurai, I.', 1),
#  ('Schmauder, S.', 1),
#  ('Kovaleva, E.', 1),
#  ('Bachmann, F.', 1),
#  ('Hawreliak, J.', 1),
#  ('Reynaud, S.', 1),
#  ('de Wit, R.', 1),
#  ('Han, S.-M.', 1),
#  ('Ahmadi, S.', 1),
#  ('Pougis, A.', 1),
#  ('Rosenthal, R.', 1),
#  ('Ebrahimian, A.', 1),
#  ('Boeff, M.', 1),
#  ('Deliktas, B.', 1),
#  ('Bouhattate, J.', 1),
#  ('Adedoyin, A.A.', 1),
#  ('Carpick, R.W.', 1),
#  ('Koseki, T.', 1),
#  ('Belak, J.', 1),
#  ('McGrath, K.M.', 1),
#  ('Merklein, M.', 1),
#  ('Mohamed, M.S.', 1),
#  ('Llorens, M.-G.', 1),
#  ('Nastasi, M.', 1),
#  ('Littlewood, P.', 1),
#  ('Villani, A.', 1),
#  ('Rosi, G.', 1),
#  ('Moore, M.A.', 1),
#  ('Shahba, A.', 1),
#  ('Howison, S.D.', 1),
#  ('Karki, B.B.', 1),
#  ('Persch, J.', 1),
#  ('Giuliani, F.', 1),
#  ('Deng, Y.', 1),
#  ('Ma, W.', 1),
#  ('Hantcherli, L.', 1),
#  ('Biswas, S.', 1),
#  ('Nikkel, D.J.', 1),
#  ('Zhuang, Z.', 1),
#  ('Yao, Z.-Q.', 1),
#  ('Dluhoš, L.', 1),
#  ('Kirkland, A.I.', 1),
#  ('Tian, L.', 1),
#  ('Remington, B.', 1),
#  ('Grujicic, M.', 1),
#  ('Gan, Z.', 1),
#  ('Tran, V.N.', 1),
#  ('Panchenko, A.', 1),
#  ('Kim, S.C.', 1),
#  ('Warren, J.M.', 1),
#  ('Kenik, E.A.', 1),
#  ('Tichy, G.', 1),
#  ('Hardy, M.', 1),
#  ('Nye, A.', 1),
#  ('Shuklinov, A.V.', 1),
#  ('Lipenkov, V.Y.', 1),
#  ('Ganghoffer, J.F.', 1),
#  ('Jackson, B.', 1),
#  ('Alabort, E.', 1),
#  ('González-Ronda, L.', 1),
#  ('Fundenberger, J.-J.', 1),
#  ('Bube, R.H.', 1),
#  ('Jiang, L.', 1),
#  ('Patel, R.J.', 1),
#  ('Mianroodi, J.R.', 1),
#  ('Morse, T.L.', 1),
#  ('Weatherly, G.C.', 1),
#  ('Budai, J.D.', 1),
#  ('Hallberg, H.', 1),
#  ('Ota, K.', 1),
#  ('Pei, Q.', 1),
#  ('Wall, J.J.', 1),
#  ('Zhou, H.', 1),
#  ('Li, W.', 1),
#  ('Kumar, N.', 1),
#  ('Cho, H.-H.', 1),
#  ('Fundenberger, J.J.', 1),
#  ('Marathe, A.', 1),
#  ('Creighton, S.L.', 1),
#  ('Rémy, B.', 1),
#  ('Polyakov, M.N.', 1),
#  ('Hu, P.', 1),
#  ('Kositski, R.', 1),
#  ('El Kazzi, S.', 1),
#  ('Hasegawa, F.', 1),
#  ('Lozovoi, A.Y.', 1),
#  ('Enayati, M.H.', 1),
#  ('Naresh-Kumar, G.', 1),
#  ('Gotman, I.', 1),
#  ('Timms, N.E.', 1),
#  ('Huang, E.-W.', 1),
#  ('Kim, K.S.', 1),
#  ('Selinger, R.L.B.', 1),
#  ('Baruchel, J.', 1),
#  ('Bleck, W.', 1),
#  ('Dai, F.-Z.', 1),
#  ('Teichert, S.', 1),
#  ('Turteltaub, S.', 1),
#  ('Cullen, D.A.', 1),
#  ('Wang, G.F.', 1),
#  ('Yang, S.', 1),
#  ('Huang, Y.C.', 1),
#  ('Badrick, A.S.T.', 1),
#  ('Park, J.B.', 1),
#  ('Besser, P.R.', 1),
#  ('Hamidreza, S.', 1),
#  ('Mahjoub, H.F.', 1),
#  ('Vukelic, S.', 1),
#  ('Jaric, J.P.', 1),
#  ('Lawrence Yao, Y.', 1),
#  ('Kret, S.', 1),
#  ('Lee, H.H.', 1),
#  ('Was, G.', 1),
#  ('Saigal, S.', 1),
#  ('Columbus, D.', 1),
#  ('Wang, Y.-D.', 1),
#  ('Miguel, M.C.', 1),
#  ('Faber, E.T.', 1),
#  ('Elhami, N.-N.', 1),
#  ('Messner, M.C.', 1),
#  ('Trebin, H.-R.', 1),
#  ('Schuh, C.A.', 1),
#  ('Elmustafa, A.A.', 1),
#  ('Zhu, J.-C.', 1),
#  ('Weiland, H.', 1),
#  ('Zhang, S.-L.', 1),
#  ('Mukherjee, S.', 1),
#  ('Sun, B.', 1),
#  ('Lee, M.-G.', 1),
#  ('Levashov, E.', 1),
#  ('Drury, M.R.', 1),
#  ('Schwarz, C.', 1),
#  ('Gillet-Chaulet, F.', 1),
#  ('Liu, X.P.', 1),
#  ('Liu, Z.', 1),
#  ('Stirland, D.J.', 1),
#  ('Marcinkowski, M.J.', 1),
#  ('Wallart, X.', 1),
#  ('Liu, X.', 1),
#  ('Ariza, E.A.', 1),
#  ('Wark, J.', 1),
#  ('Zhao, D.', 1),
#  ('Barcelo, F.', 1),
#  ('Li, B.', 1),
#  ('Ye, W.', 1),
#  ('Yadegari, S.', 1),
#  ('Savall, C.', 1),
#  ('Eisenberg, M.A.', 1),
#  ('Yaghoobi, M.', 1),
#  ('Chen, W.', 1),
#  ('Wittry, D.B.', 1),
#  ('Raina, A.', 1),
#  ('Mehdi, A.', 1),
#  ('Nastishin, Y.', 1),
#  ('di Forte-Poisson, M.A.', 1),
#  ('Schwartz, J.', 1),
#  ('Bruschi, S.', 1),
#  ('Kitamura, T.', 1),
#  ('Castelnau, O.', 1),
#  ('Carter, W.J.', 1),
#  ('Dunand, D.C.', 1),
#  ('Rezvanian, O.', 1),
#  ('Shollock, B.', 1),
#  ('Duan, Y.-S.', 1),
#  ('Valek, B.C.', 1),
#  ('Xue, X.', 1),
#  ('Batterman, B.W.', 1),
#  ('Nishida, M.', 1),
#  ('Yang, R.', 1),
#  ('Iltis, X.', 1),
#  ('Perreault, B.', 1),
#  ('Kitazono, K.', 1),
#  ('Titchener, J.B.', 1),
#  ('Hildebrand, F.E.', 1),
#  ('Hughes, G.', 1),
#  ('Dawson, P.R.', 1),
#  ('Hodgson, P.D.', 1),
#  ('Kundu, A.', 1),
#  ('Fredriksson, P.', 1),
#  ('Freudenberger, J.', 1),
#  ('Faria, S.H.', 1),
#  ('Saif, M.T.A.', 1),
#  ('Peng, B.', 1),
#  ('Sedao, X.', 1),
#  ('Weygand, D.', 1),
#  ('Zhang, J.C.', 1),
#  ('Ruterana, P.', 1),
#  ('Schouwenaars, R.', 1),
#  ('Yang, Y.', 1),
#  ('Kluender, R.T.', 1),
#  ('Prior, D.J.', 1),
#  ('Park, L.J.', 1),
#  ('Wright, L.', 1),
#  ('Korenkov, V.V.', 1),
#  ('Luccarelli, P.G.', 1),
#  ('Anderson, I.', 1),
#  ('Faleskog, J.', 1),
#  ('Cuitiño, A.M.', 1),
#  ('Déprés, C.', 1),
#  ("Solov'Yov, A.V.", 1),
#  ('Weingarten, N.S.', 1),
#  ('Brauer, S.', 1),
#  ('Hsia, K.J.', 1),
#  ('Dai, F.', 1),
#  ('Park, D.Y.', 1),
#  ('Mani, K.V.', 1),
#  ('Milman, Y.V.', 1),
#  ('Prahl, U.', 1),
#  ('Glazoff, M.V.', 1),
#  ('Haghshenas, M.', 1),
#  ('Borbely, A.', 1),
#  ('Mendis, B.G.', 1),
#  ('Svirina, J.V.', 1),
#  ('Dudeck, K.J.', 1),
#  ('Aubry, S.', 1),
#  ('Lee, J.H.', 1),
#  ('Kumar, V.', 1),
#  ('Eve, S.', 1),
#  ('Piao, Y.', 1),
#  ('Kreuzer, H.G.M.', 1),
#  ('Moulinec, H.', 1),
#  ('Sievert, R.', 1),
#  ('Kawabata, K.', 1),
#  ('Gullett, P.', 1),
#  ('Admal, N.C.', 1),
#  ('Quek, S.S.', 1),
#  ('Hafez Haghighat, S.M.', 1),
#  ('Evans, J.T.', 1),
#  ('Valanis, K.C.', 1),
#  ('Balint, D.S.', 1),
#  ('Ming, P.', 1),
#  ('Shvets, I.V.', 1),
#  ('Zhou, K.', 1),
#  ('McClelland, Z.', 1),
#  ('Schoenung, J.M.', 1),
#  ('Huang, B.', 1),
#  ('Rugg, D.', 1),
#  ('Entemeyer, D.', 1),
#  ('Di, H.S.', 1),
#  ('Joo, Y.-C.', 1),
#  ('Liaw, P.K.', 1),
#  ('Radikan, K.', 1),
#  ('Di, H.', 1),
#  ('Nigam, A.N.', 1),
#  ('van Goethem, N.', 1),
#  ('Takahashi, T.', 1),
#  ('Porta, M.', 1),
#  ('Ahmed, S.', 1),
#  ('Ord, A.', 1),
#  ('Nguyen, Q.S.', 1),
#  ('Koifman, K.G.', 1),
#  ('Nygårds, M.', 1),
#  ('Zhu, T.T.', 1),
#  ('Pellegrini, Y.-P.', 1),
#  ('Pike, L.M.', 1),
#  ('Pataky, G.J.', 1),
#  ('Mordehai, D.', 1),
#  ('Iqbal, M.Z.', 1),
#  ('Chang, H.-J.', 1),
#  ('Popov, V.L.', 1),
#  ('Bolle, B.', 1),
#  ('Dedo, A.', 1),
#  ('Sheng, D.', 1),
#  ('Dodds, R.H.', 1),
#  ('Teichtmeister, S.', 1),
#  ('Arioka, K.', 1),
#  ('Ohori, K.', 1),
#  ('Leoni, G.', 1),
#  ('Van Uffelen, P.', 1),
#  ('Meyer, C.', 1),
#  ('Cleveringa, H.H.M.', 1),
#  ('Cheng, J.', 1),
#  ('Drummy, L.F.', 1),
#  ('Mura, T.', 1),
#  ('Liu, G.', 1),
#  ('Prokoshkin, S.', 1),
#  ('Lapovok, R.', 1),
#  ('Duan, D.-M.', 1),
#  ('Schmauch, J.', 1),
#  ('Almer, J.', 1),
#  ('Gerken, J.M.', 1),
#  ('Neugebauer, R.', 1),
#  ('Carsley, J.E.', 1),
#  ('Golovin, Yu.I.', 1),
#  ('Sangid, M.D.', 1),
#  ('Zahn, G.', 1),
#  ('Schikorra, M.', 1),
#  ('Lebedkina, T.', 1),
#  ('Gray, G.T.', 1),
#  ('Kaluza, M.', 1),
#  ('Jensen, D.J.', 1),
#  ('Ishibashi, Y.', 1),
#  ('Higashi, Y.', 1),
#  ('Kang, J.-Y.', 1),
#  ('Kondo, D.', 1),
#  ('Mandadapu, K.K.', 1),
#  ('Perrin, C.', 1),
#  ('Hu, R.', 1),
#  ('Foletti, S.', 1),
#  ('Desplanque, L.', 1),
#  ('Reese, E.D.', 1),
#  ('Kok, S.', 1),
#  ('Ren, Y.', 1),
#  ('Bollhalder, A.', 1),
#  ('Chernov, A.A.', 1),
#  ('Ziemann, M.', 1),
#  ('Solas, D.', 1),
#  ('Muller, G.M.', 1),
#  ('Gray III, G.T.', 1),
#  ('Arul Kumar, M.', 1),
#  ('Craig, G.B.', 1),
#  ('Alkorta, J.', 1),
#  ('Wei, C.C.', 1),
#  ('Mughal, A.', 1),
#  ('Habler, G.', 1),
#  ('Bergmann, R.', 1),
#  ('Kim, M.', 1),
#  ('Ye, N.', 1),
#  ('Zhang, Z.J.', 1),
#  ('Song En Low, T.', 1),
#  ('Mach, J.C.', 1),
#  ('Romano, G.', 1),
#  ('Littrell, K.C.', 1),
#  ('Ram, F.', 1),
#  ('Etesami, S.A.', 1),
#  ('Hemker, K.J.', 1),
#  ('Mourad, H.M.', 1),
#  ('Dhouibi, S.', 1),
#  ('Bird, M.W.', 1),
#  ('Slaughter, W.S.', 1),
#  ('Ezaz, T.', 1),
#  ('Shibata, A.', 1),
#  ('Nettleton, R.E.', 1),
#  ('Zhao, Y.', 1),
#  ('Chen, J.', 1),
#  ('Tran, T.N.', 1),
#  ('Gu, C.F.', 1),
#  ('Fereiduni, E.', 1),
#  ('Ilavsky, J.', 1),
#  ('Chiang, C.R.', 1),
#  ('Borca, C.N.', 1),
#  ('Moussa, C.', 1),
#  ('Sudmanns, M.', 1),
#  ('Ali, U.', 1),
#  ('Kadkhodapour, J.', 1),
#  ('Lejček, L.', 1),
#  ('Huang, H.', 1),
#  ('Manjul', 1),
#  ('Linder, C.', 1),
#  ('Louchet, F.', 1),
#  ('Moody, M.', 1),
#  ('Yoo, J.S.', 1),
#  ('He, W.', 1),
#  ('Matsuki, Y.', 1),
#  ('Calabri, L.', 1),
#  ('Maudlin, P.J.', 1),
#  ('Chaussidon, J.', 1),
#  ('Chèze, C.', 1),
#  ('Feaugas, X.', 1),
#  ('Guéninchault, N.', 1),
#  ('Gaubert, A.', 1),
#  ('Ziaei-Rad, S.', 1),
#  ('Lim, H.', 1),
#  ('Proudhon, H.', 1),
#  ('Gornakov, V.', 1),
#  ('Oudriss, A.', 1),
#  ...]

# %%
def parseAffiliation( aff ):
    ''' take the affiliation string (already splited)
    '''
    aff = aff.split(',')
    country = aff[-1].strip()
    city = aff[-2].strip()
    
    return city, country

# %%
authorAffiliation = {}
for auth, keys in biblio.authors.items():
    authorAffiliation[auth] = []
    
    for key in keys:
        article = biblio.getArticleFromKey(key)
        affiliations = [ parseAffiliation(aff) for aff in article.affiliation ]
        
        authorAffiliation[auth].extend( affiliations )

# %%
authorAffiliation
# Out:
# {'White, K.W.': [('TX', 'United States'),
#   ('UT', 'United States'),
#   ('TN', 'United States')],
#  'Wang, X.': [('Shanghai', 'China'),
#   ('Shanghai', 'China'),
#   ('Shanghai', 'China'),
#   ('Hubei', 'China')],
#  'Shuvarin, I.A.': [('Tambov', 'Russian Federation'),
#   ('Moscow', 'Russian Federation')],
#  'Cho, J.-S.': [('Seoul 151-742', 'South Korea'),
#   ('PA 15213', 'United States'),
#   ('Kyunggi-Do 151-742', 'South Korea')],
#  'Saha, R.': [('100084', 'China'),
#   ('CA 94305', 'United States'),
#   ('IL 61801', 'United States'),
#   ('PA 15069', 'United States')],
#  'Hardin, T.J.': [('UT', 'United States'),
#   ('MA', 'United States'),
#   ('OH', 'United States'),
#   ('UT 84602', 'United States'),
#   ('OH 43210', 'United States')],
#  'Omiya, M.': [('Aichi', 'Japan'),
#   ('Tokyo', 'Japan'),
#   ('Kanagawa', 'Japan'),
#   ('Kanagawa', 'Japan'),
#   ('Tokyo', 'Japan')],
#  'Wright, J.P.': [('Kgs. Lyngby', 'Denmark'),
#   ('Grenoble', 'France'),
#   ('IL', 'United States'),
#   ('Kgs. Lyngby', 'Denmark')],
#  'Ding, H.': [('Wuhan 430074', 'China'),
#   ('Wuhan 430074', 'China'),
#   ('London E1 4NS', 'United Kingdom')],
#  'Yun, G.': [('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Ont. L8S 4L7', 'Canada'),
#   ('NM 87545', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Ont. K7L 5L9', 'Canada')],
#  'Masoumi, M.': [('SP', 'Brazil')],
#  'Grilli, N.': [('Villigen PSI', 'Switzerland'),
#   ('Lausanne', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Lausanne', 'Switzerland'),
#   ('Villigen', 'Switzerland'),
#   ('Villigen', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Lausanne', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Baden-Dättwil', 'Switzerland')],
#  'Huang, J.': [('Beijing', 'China'),
#   ('Beijing', 'China'),
#   ('Beijing', 'China'),
#   ('Kowloon', 'Hong Kong'),
#   ('Zhejiang', 'China'),
#   ('Wuhan', 'China'),
#   ('NC', 'United States')],
#  'Kondo, R.': [('Kohoku-ku Yokohama', 'Japan'),
#   ('Saga', 'Japan'),
#   ('Yokohama', 'Japan')],
#  'Uchic, M.': [('IL 61801', 'United States'),
#   ('MA 02139', 'United States'),
#   ('District of Columbia 20585', 'United States'),
#   ('CA 95616', 'United States'),
#   ('CA 94550', 'United States'),
#   ('WA 99164', 'United States'),
#   ('4000 Roskilde', 'Denmark'),
#   ('TN 37831', 'United States'),
#   ('NH 03755', 'United States'),
#   ('IL 60208', 'United States'),
#   ('DK-2800 Kongens Lyngby', 'Denmark'),
#   ('IL 60439', 'United States'),
#   ('WI 53711', 'United States'),
#   ('Oxford OX1 3PH', 'United Kingdom'),
#   ('NM 87545', 'United States'),
#   ('PA 15213', 'United States'),
#   ('PA 19104', 'United States'),
#   ('AL 35487', 'United States'),
#   ('Ohio 45433', 'United States'),
#   ('TN 37831', 'United States'),
#   ('MI 48109', 'United States')],
#  'Wu, R.': [('Fürth', 'Germany'), ('Freiberg', 'Germany')],
#  'Nong, Z.-S.': [('Harbin 150001', 'China')],
#  'Cuo, T.F.': [('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('MI 49931', 'United States')],
#  'AbuOmar, O.': [('MI 49931', 'United States'),
#   ('MS 39762', 'United States'),
#   ('MS 39759', 'United States')],
#  'Tyapunina, N.A.': [('Moscow', 'Russian Federation')],
#  'Busso, E.P.': [('91003 Evry', 'France'),
#   ('91003 Evry Cedex', 'France'),
#   ('57078 Metz', 'France'),
#   ('57070 Metz', 'France'),
#   ('91003 Evry Cedex', 'France'),
#   ('92322 Chatillon Cedex', 'France'),
#   ('London SW7 2BX', 'United Kingdom'),
#   ('CA 9455-0808', 'United States'),
#   ('London SW7 2BX', 'United Kingdom'),
#   ('London', 'United Kingdom')],
#  'Horstemeyer, M.F.': [('Mississippi State University StarkvilleMS',
#    'United States'),
#   ('Mississippi State University StarkvilleMS', 'United States'),
#   ('MS', 'United States'),
#   ('NV', 'United States'),
#   ('MI', 'United States'),
#   ('MI 49931', 'United States'),
#   ('MS 39762', 'United States'),
#   ('MS 39759', 'United States'),
#   ('MI 49931', 'United States'),
#   ('MS 39759', 'United States'),
#   ('CA 94551-0969', 'United States'),
#   ('GA 30332-0405', 'United States')],
#  'Owen, D.R.': [('Lisboa', 'Portugal'),
#   ('Lisboa', 'Portugal'),
#   ('Garching bei München', 'Germany'),
#   ('PA', 'United States')],
#  'Garikipati, K.': [('University of Colorado at Boulder', 'United States'),
#   ('San Diego', 'United States'),
#   ('Ann Arbor', 'United States'),
#   ('MI 48109-3170', 'United States'),
#   ('CA 94551', 'United States'),
#   ('CA 94551-0969', 'United States'),
#   ('MI', 'United States')],
#  'Zilahi, G.': [('Kowloon', 'Hong Kong'), ('Budapest', 'Hungary')],
#  'Svendsen, B.': [('Aachen', 'Germany'),
#   ('NM', 'United States'),
#   ('Düsseldorf', 'Germany'),
#   ('Hamburg', 'Germany'),
#   ('Aachen', 'Germany'),
#   ('Düsseldorf', 'Germany'),
#   ('Saarbrücken', 'Germany'),
#   ('CA 91125', 'United States'),
#   ('Dortmund University of Technology', 'Germany'),
#   ('RWTH Aachen University', 'Germany'),
#   ('Dortmund', 'Germany'),
#   ('Aachen', 'Germany'),
#   ('Gothenburg', 'Sweden'),
#   ('44227 Dortmund', 'Germany'),
#   ('64289 Darmstadt', 'Germany'),
#   ('22100 Lund', 'Sweden'),
#   ('D-44221 Dortmund', 'Germany'),
#   ('D-44227 Dortmund', 'Germany'),
#   ('D-12200 Berlin', 'Germany'),
#   ('D-44227 Dortmund', 'Germany'),
#   ('D-44227 Dortmund', 'Germany')],
#  'Merriman, C.C.': [('WA 99164-2920', 'United States'), ('Metz', 'France')],
#  'Deliktas, B.': [('LA 70803', 'United States'), ('Hatay 31200', 'Turkey')],
#  'Javili, A.': [('Hannover', 'Germany'),
#   ('Rondebosch', 'South Africa'),
#   ('Erlangen', 'Germany')],
#  'Onuki, Y.': [('The University of Tokyo', 'Japan')],
#  'Roy, A.': [('Ankara', 'Turkey'),
#   ('Thun', 'Switzerland'),
#   ('Loughborough University', 'United Kingdom'),
#   ('CA 91125', 'United States'),
#   ('LE11 3TU', 'United Kingdom'),
#   ('PA 15213', 'United States'),
#   ('OH 45433-7817', 'United States'),
#   ('PA', 'United States'),
#   ('5600 MB Eindhoven', 'Netherlands'),
#   ('PA 15213', 'United States')],
#  'Osterbrink, F.': [('Paderborn', 'Germany'),
#   ('Essen', 'Germany'),
#   ('Essen', 'Germany'),
#   ('Essen', 'Germany'),
#   ('Iaşi', 'Romania')],
#  'Leff, A.C.': [('PA', 'United States'),
#   ('CA', 'United States'),
#   ('PA', 'United States'),
#   ('PA', 'United States'),
#   ('CO', 'United States'),
#   ('PA', 'United States'),
#   ('PA', 'United States')],
#  'Ghosh, S.': [('MD', 'United States'),
#   ('MD', 'United States'),
#   ('MD 21218', 'United States'),
#   ('OH 43210', 'United States'),
#   ('OH 43210', 'United States'),
#   ('MD 21218', 'United States'),
#   ('OH 43210', 'United States')],
#  'Koifman, K.G.': [('Moscow', 'Russian Federation')],
#  'Oh, K.H.': [('Changwon', 'South Korea'),
#   ('OR', 'United States'),
#   ('Seoul 151-744', 'South Korea'),
#   ('Seoul 151-744', 'South Korea'),
#   ('Seoul 151-744', 'South Korea'),
#   ('Seoul 151-742', 'South Korea'),
#   ('PA 15213', 'United States'),
#   ('Kyunggi-Do 151-742', 'South Korea')],
#  'Kou, H.': [("Xi'an", 'China')],
#  'Kioseoglou, J.': [('GR-54124 Thessaloniki', 'Greece'),
#   ('GR-54124 Thessaloniki', 'Greece'),
#   ('MI 49931', 'United States')],
#  'Lebensohn, R.': [('Tübingen', 'Germany'),
#   ('Bremerhaven', 'Germany'),
#   ('Bellaterra (Barcelona)', 'Spain'),
#   ('Los Alamos National LaboratoryNM', 'United States'),
#   ('VIC', 'Australia')],
#  'Schultz, L.': [('Dresden', 'Germany'),
#   ('Dresden', 'Germany'),
#   ('Freiberg', 'Germany')],
#  'Belassel, M.': [('Metz Cedex 3 57078', 'France'),
#   ('Angers Cedex 49035', 'France'),
#   ('Ont. N0R 1L0', 'Canada')],
#  'Evans, L.': [('Tübingen', 'Germany'),
#   ('Bremerhaven', 'Germany'),
#   ('Bellaterra (Barcelona)', 'Spain'),
#   ('Los Alamos National LaboratoryNM', 'United States'),
#   ('VIC', 'Australia')],
#  'Feng, G.': [('IL 61801', 'United States'),
#   ('100084', 'China'),
#   ('CA 94305', 'United States'),
#   ('TN 37996', 'United States'),
#   ('TN 37831', 'United States')],
#  'Timms, N.E.': [('WA 6845', 'Australia'),
#   ('4000 Roskilde', 'Denmark'),
#   ('9500 Hobro', 'Denmark'),
#   ('181 22 Lidingö', 'Sweden')],
#  'Hoagland, R.G.': [('NM 87545', 'United States')],
#  'Reddy, S.M.': [('WA 6845', 'Australia'),
#   ('4000 Roskilde', 'Denmark'),
#   ('9500 Hobro', 'Denmark'),
#   ('181 22 Lidingö', 'Sweden')],
#  'Viatkina, E.M.': [('5600 MB Eindhoven', 'Netherlands'),
#   ('2600 GA Delft', 'Netherlands')],
#  'Berdichevsky, V.L.': [('MI 48202', 'United States'),
#   ('MI 48202', 'United States')],
#  'Kumar, G.R.': [('Bangalore', 'India'),
#   ('Bangalore', 'India'),
#   ('Mumbai', 'India'),
#   ('Bangalore', 'India')],
#  'Dong, J.': [("Xi'an 710072", 'China')],
#  'Ramazani, A.': [('D-52072 Aachen', 'Germany'),
#   ('D-52074 Aachen', 'Germany'),
#   ('D-52074 Aachen', 'Germany')],
#  'Gu, C.': [('Metz', 'France'),
#   ('Vic. 3800', 'Australia'),
#   ('Vic.', 'Australia')],
#  'Gruber, P.A.': [('Karlsruhe', 'Germany'),
#   ('Karlsruhe', 'Germany'),
#   ('Aachen', 'Germany'),
#   ('Düsseldorf', 'Germany'),
#   ('Leoben', 'Austria'),
#   ('CA', 'United States')],
#  'Bassani, J.L.': [('PA 15213', 'United States'),
#   ('PA 19104', 'United States'),
#   ('IL 61801', 'United States'),
#   ('PA 19104', 'United States'),
#   ('PA 19104', 'United States'),
#   ('RI 02912', 'United States'),
#   ('2628 CD Delft', 'Netherlands'),
#   ('IL 61801', 'United States'),
#   ('PA 19104', 'United States')],
#  'Clement, A.': [('57045', 'France'),
#   ('31062', 'France'),
#   ('30-059', 'Poland')],
#  'Moser, B.': [('CH-1015 Lausanne', 'Switzerland')],
#  'Micha, J.-S.': [('A-8700 Leoben', 'Austria'),
#   ('Montanuniversität Leoben', 'Austria'),
#   ('CEA-Grenoble/Institut Nanosciences et Cryogénie', 'France'),
#   ('CRG-IF BM32 at ESRF', 'France')],
#  'Poh, L.H.': [('5600 MB Eindhoven', 'Netherlands'),
#   ('Singapore', 'Singapore')],
#  'Regueiro, R.A.': [('University of Colorado at Boulder', 'United States'),
#   ('San Diego', 'United States'),
#   ('Ann Arbor', 'United States'),
#   ('MI 48109-3170', 'United States'),
#   ('CA 94551', 'United States'),
#   ('CA 94551-0969', 'United States'),
#   ('MI', 'United States')],
#  'Kübel, C.': [('MI 48109', 'United States'),
#   ('5600 KA Eindhoven', 'Netherlands'),
#   ('MI 48105', 'United States'),
#   ('MI 48109-2136', 'United States'),
#   ('MI 48121-2053', 'United States'),
#   ('MI 48109-2136', 'United States')],
#  'Pinna, C.': [('Universitätsstr. 90 aBochum', 'Germany'),
#   ('Coventry', 'United Kingdom'),
#   ('Sheffield', 'United Kingdom'),
#   ('Coventry', 'United Kingdom')],
#  'Mishra, R.S.': [('TX', 'United States'),
#   ('MO 65409', 'United States'),
#   ('MO 63166', 'United States')],
#  'Pike, L.M.': [('TN', 'United States'),
#   ('TN', 'United States'),
#   ('Jhongli', 'Taiwan'),
#   ('NM 87545', 'United States'),
#   ('IL', 'United States'),
#   ('IN', 'United States')],
#  'Myers, M.T.': [('CA 94550', 'United States'),
#   ('TX 77843', 'United States'),
#   ('TX 77843', 'United States'),
#   ('TX 77843', 'United States')],
#  'Williams, W.S.': [('IL 61801', 'United States')],
#  'Chang, H.-J.': [('Evry', 'France'),
#   ('Annecy', 'France'),
#   ('Grenoble', 'France')],
#  'Seefeldt, M.': [('DK-4000 Roskilde', 'Denmark'),
#   ('Moscow 119049', 'Russian Federation'),
#   ('Ufa 450000', 'Russian Federation'),
#   ('28906 Madrid', 'Spain'),
#   ('60438 Frankfurt am Main', 'Germany'),
#   ('Haifa 32000', 'Israel'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('CZ72525 Ostrava', 'Czech Republic'),
#   ('Leuven', 'Belgium'),
#   ('04510 México DF', 'Mexico'),
#   ('B-3001 Leuven', 'Belgium'),
#   ('191015 St.-Petersburg', 'Russian Federation'),
#   ('Heverlee', 'Belgium')],
#  'Wagoner, R.H.': [('UT', 'United States'),
#   ('UT', 'United States'),
#   ('PA', 'United States'),
#   ('OH', 'United States'),
#   ('UT 84602', 'United States'),
#   ('OH 43210', 'United States'),
#   ('OH 43210', 'United States'),
#   ('Gyeongbuk 790-784', 'South Korea'),
#   ('Gyeongnam 641-831', 'South Korea'),
#   ('UT 84601', 'United States')],
#  'Tho, K.K.': [('Singapore 119260', 'Singapore'),
#   ('Singapore 117528', 'Singapore'),
#   ('119260', 'Singapore'),
#   ('117528', 'Singapore'),
#   ('Singapore 119260', 'Singapore'),
#   ('Singapore 117528', 'Singapore'),
#   ('Singapore 119260', 'Singapore'),
#   ('Singapore 117528', 'Singapore')],
#  'Ebobisse, F.': [('7701 Rondebosch', 'South Africa'),
#   ('45141 Essen', 'Germany')],
#  'Kobas, M.': [('CH-8093 Zurich', 'Switzerland'),
#   ('CH-5400 Baden', 'Switzerland')],
#  'Steigmann, D.J.': [('208016', 'India'), ('CA 94720', 'United States')],
#  'Dub, S.N.': [('Kiev', 'Ukraine'),
#   ('Kiev', 'Ukraine'),
#   ('03142 Kiev', 'Ukraine'),
#   ('04074 Kiev', 'Ukraine')],
#  'Brodsky, E.E.': [('PA', 'United States'),
#   ('CA', 'United States'),
#   ('PA', 'United States'),
#   ('TX', 'United States'),
#   ('TN', 'United States')],
#  'Tsui, T.Y.': [('NM 87545', 'United States'),
#   ('ON N2L 3G1', 'Canada'),
#   ('CA 91125', 'United States'),
#   ('Daejeon 305-701', 'South Korea'),
#   ('CA 94720', 'United States'),
#   ('Ont. N2L 3G1', 'Canada'),
#   ('CA 91125', 'United States'),
#   ('NM 87545', 'United States'),
#   ('CA 94720', 'United States')],
#  'Srinivasan, K.': [('IN 47907', 'United States'),
#   ('IL 60208', 'United States'),
#   ('A-8700 Leoben', 'Austria')],
#  'Matias, J.': [('Lisboa', 'Portugal'),
#   ('Lisboa', 'Portugal'),
#   ('Garching bei München', 'Germany'),
#   ('PA', 'United States')],
#  'Godefroy, S.': [('KY 40506-0027', 'United States'),
#   ('TN 37831-6064', 'United States')],
#  'Faghihi, D.': [('LA', 'United States'),
#   ('TX', 'United States'),
#   ('LA 70803', 'United States'),
#   ('Seoul', 'South Korea'),
#   ('TX 78712', 'United States'),
#   ('LA 70803', 'United States'),
#   ('70803', 'United States'),
#   ('70803', 'United States')],
#  'Aydelotte, B.': [('UT 84602', 'United States'), ('UT', 'United States')],
#  'Evers, L.P.': [('Netherlands Inst. for Met. Research', 'Netherlands'),
#   ('5600 MB Eindhoven', 'Netherlands'),
#   ('2600 G A Delft', 'Netherlands'),
#   ('5600 MB Eindhoven', 'Netherlands'),
#   ('Netherlands Institute for Metals Research (NIMR)', 'Netherlands'),
#   ('5600 MB Eindhoven', 'Netherlands'),
#   ('MA 02139', 'United States'),
#   ('5600 MB Eindhoven', 'Netherlands')],
#  'Zhao, H.': [('Dalian 116028', 'China')],
#  'Winwood, S.': [('Swansea', 'United Kingdom'),
#   ('Huddersfield', 'United Kingdom')],
#  'Schulz, K.': [('Karlsruhe', 'Germany'),
#   ('Freiburg', 'Germany'),
#   ('76131 Karlsruhe', 'Germany'),
#   ('90762 Fürth', 'Germany'),
#   ('79108 Freiburg', 'Germany')],
#  'Pipard, J.-M.': [('F-57078 Metz Cedex 03', 'France'),
#   ('F-57283 Maizières-les-Metz', 'France')],
#  'Li, S.': [('Shanghai', 'China'),
#   ('Shanghai', 'China'),
#   ('Shanghai', 'China'),
#   ('CA 94720', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94550', 'United States')],
#  'Finel, A.': [('Châtillon', 'France')],
#  'Liang, J.': [('Beijing', 'China'),
#   ('Beijing', 'China'),
#   ('Beijing', 'China'),
#   ('Beijing', 'China')],
#  'Tian, Y.Z.': [('Shenyang', 'China'), ('Beijing', 'China')],
#  'Zhang, B.': [('Wuhan 430074', 'China'),
#   ('Wuhan 430074', 'China'),
#   ('London E1 4NS', 'United Kingdom')],
#  'Basinger, J.': [('UT 84602', 'United States'),
#   ('NY 10027', 'United States'),
#   ('UT 84602', 'United States')],
#  'Sprackling, M.T.': [('WC2R 2LS', 'United Kingdom'),
#   ('WC2R 2LS', 'United Kingdom'),
#   ('W8 7AH', 'United Kingdom'),
#   ('London', 'United Kingdom')],
#  'Calcagnotto, M.': [('Isfahan 84156-83111', 'Iran'),
#   ('Stuttgart', 'Germany'),
#   ('Düsseldorf', 'Germany'),
#   ('40237 Düsseldorf', 'Germany')],
#  'Walter, M.': [('Karlsruhe', 'Germany'),
#   ('Karlsruhe', 'Germany'),
#   ('Aachen', 'Germany'),
#   ('Düsseldorf', 'Germany'),
#   ('Leoben', 'Austria'),
#   ('CA', 'United States')],
#  'Pagan, D.C.': [('Cornell High Energy Synchrotron Source', 'United States'),
#   ('Cornell University', 'United States'),
#   ('Argonne National Laboratory', 'United States'),
#   ('Lawrence Livermore National Laboratory', 'United States'),
#   ('Cornell University', 'United States'),
#   ('Cornell High Energy Synchrotron Source', 'United States'),
#   ('NY', 'United States')],
#  'Shet, C.': [('PA 15213-3890', 'United States'),
#   ('PA 15213-3890', 'United States'),
#   ('CA 94550', 'United States')],
#  'Zhang, H.': [('Shanghai', 'China'),
#   ('Düsseldorf', 'Germany'),
#   ('Shanghai', 'China'),
#   ('Düsseldorf', 'Germany')],
#  'Tsivinsky, S.V.': [("Lenin's Prospect 47", 'Kharkov')],
#  'Cho, Y.': [('Seoul 151-744', 'South Korea'),
#   ('Seoul 151-744', 'South Korea')],
#  'Baek, S.M.': [('Pohang', 'South Korea'),
#   ('Pohang', 'South Korea'),
#   ('Pohang', 'South Korea')],
#  'Sellers, S.': [('Torino', 'Italy'),
#   ('Norwich', 'United Kingdom'),
#   ('I-10123 Torino', 'Italy'),
#   ('Norwich NR4 7TJ', 'United Kingdom')],
#  'Haussy, B.': [('54054 Vandoeuvre Cedex', 'France'),
#   ('49009 Angers Cedex', 'France')],
#  'Xu, D.S.': [('Shenyang 110016', 'China'), ('Beijing 100039', 'China')],
#  'Van Goethem, N.': [('Lisboa', 'Portugal'),
#   ('Avignon', 'France'),
#   ('Lisboa', 'Portugal'),
#   ('1649-003 Lisboa', 'Portugal'),
#   ('1348 Louvain-la-Neuve', 'Belgium'),
#   ('Lisboa 1649-003', 'Portugal')],
#  'Petrov, R.': [('Fiat Automóveis', 'Brazil'),
#   ('Ghent University', 'Belgium')],
#  'Engel, U.': [('Erlangen 91058', 'Germany'),
#   ('91058 Erlangen', 'Germany'),
#   ('Erlangen 91058', 'Germany'),
#   ('Ont. K7L 3N6', 'Canada'),
#   ('Nuremberg', 'Germany'),
#   ('University of Dortmund', 'Germany'),
#   ('Katholiek Universiteit Leuven', 'Belgium'),
#   ('University of Chemnitz', 'Germany'),
#   ('University of Padua', 'Italy'),
#   ('91058 Erlangen', 'Germany')],
#  'Fedelich, B.': [('92322 Chatîllon Cedex', 'France'),
#   ('12205 Berlin', 'Germany'),
#   ('12200 Berlin', 'Germany')],
#  'Peraudeau, B.': [('La Rochelle Cedex 01', 'France')],
#  'Hu, A.': [('Jiangsu', 'China'), ('Hubei', 'China')],
#  'Chandra, A.': [('IL 61801', 'United States')],
#  'Ferreira, R.F.': [('Fiat Automóveis', 'Brazil'),
#   ('Ghent University', 'Belgium')],
#  'Salvat Cantó, J.': [('Swansea', 'United Kingdom'),
#   ('Huddersfield', 'United Kingdom')],
#  'Basaran, C.': [('NY 14260', 'United States'), ('NY 14260', 'United States')],
#  'Ammar, K.': [('BP 87 91003Evry', 'France'),
#   ('Nancy', 'France'),
#   ('Châtillon Cedex', 'France'),
#   ('Villetaneuse', 'France')],
#  'Zimmerman, J.A.': [('CA 94550', 'United States')],
#  'Reuber, C.': [('40237 Düsseldorf', 'Germany'),
#   ('MI 48824', 'United States')],
#  'Morris Jr., J.W.': [('CA 94720', 'United States'),
#   ('CA 94551', 'United States'),
#   ('CA 94720', 'United States')],
#  'Browning, N.D.': [('IL 61801', 'United States'),
#   ('MA 02139', 'United States'),
#   ('District of Columbia 20585', 'United States'),
#   ('CA 95616', 'United States'),
#   ('CA 94550', 'United States'),
#   ('WA 99164', 'United States'),
#   ('4000 Roskilde', 'Denmark'),
#   ('TN 37831', 'United States'),
#   ('NH 03755', 'United States'),
#   ('IL 60208', 'United States'),
#   ('DK-2800 Kongens Lyngby', 'Denmark'),
#   ('IL 60439', 'United States'),
#   ('WI 53711', 'United States'),
#   ('Oxford OX1 3PH', 'United Kingdom'),
#   ('NM 87545', 'United States'),
#   ('PA 15213', 'United States'),
#   ('PA 19104', 'United States'),
#   ('AL 35487', 'United States'),
#   ('Ohio 45433', 'United States'),
#   ('TN 37831', 'United States'),
#   ('MI 48109', 'United States')],
#  'Gong, Y.': [('Yunnan', 'China'),
#   ('Jiangsu', 'China'),
#   ('Beijing', 'China'),
#   ('NC', 'United States')],
#  'Duflou, J.': [('Ont. K7L 3N6', 'Canada'),
#   ('Nuremberg', 'Germany'),
#   ('University of Dortmund', 'Germany'),
#   ('Katholiek Universiteit Leuven', 'Belgium'),
#   ('University of Chemnitz', 'Germany'),
#   ('University of Padua', 'Italy')],
#  'Golubenko, A.A.': [('Kiev', 'Ukraine'),
#   ('Kiev', 'Ukraine'),
#   ('03142 Kiev', 'Ukraine'),
#   ('04074 Kiev', 'Ukraine')],
#  'De Hosson, J.T.M.': [('AG Groningen', 'Netherlands')],
#  'Zhang, M.': [('Beijing', 'China')],
#  'Rey, C.': [('Châtenay-Malabry', 'France'),
#   ('Orsay', 'France'),
#   ('Orsay', 'France'),
#   ('Gif-sur-Yvette', 'France'),
#   ('Bologne', 'France'),
#   ('F-92295 Chatenay-Malabry', 'France'),
#   ('F-77818 Moret-sur-Loing', 'France'),
#   ('F-91191 Gif-sur-Yvette', 'France'),
#   ('93206', 'France')],
#  'Pigeon, F.': [('F-42023 Saint-Etienne', 'France'),
#   ('F-42023 Saint-Etienne', 'France')],
#  'Jackson, B.E.': [('UT', 'United States'),
#   ('UT', 'United States'),
#   ('PA', 'United States'),
#   ('OH', 'United States')],
#  'Capolungo, L.': [('Metz', 'France'),
#   ('Saint-Etienne', 'France'),
#   ('Los Alamos National LaboratoryNM', 'United States'),
#   ('Metz Cedex', 'France'),
#   ('NM', 'United States'),
#   ('GA', 'United States'),
#   ('Metz Cedex', 'France'),
#   ('Metz Cedex', 'France'),
#   ('NM', 'United States'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Metz Cedex', 'France'),
#   ('Metz Cedex', 'France'),
#   ('57045 Metz Cedex', 'France'),
#   ('57070 Metz Cedex', 'France'),
#   ('57070 Metz', 'France'),
#   ('NM 87545', 'United States'),
#   ('57045 Metz Cedex', 'France'),
#   ('57070 Metz Cedex', 'France'),
#   ('57045 Metz Cedex', 'France'),
#   ('57070 Metz Cedex', 'France'),
#   ('57070 Metz', 'France'),
#   ('57045 Metz Cedex', 'France')],
#  'Basavaraj, V.': [('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('TX', 'United States'),
#   ('TX', 'United States'),
#   ('Mumbai', 'India')],
#  'Grolimund, D.': [('Villigen PSI', 'Switzerland'),
#   ('Lausanne', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Baden-Dättwil', 'Switzerland')],
#  'Cho, J.-H.': [('Seoul 151-742', 'South Korea'),
#   ('PA 15213', 'United States'),
#   ('Kyunggi-Do 151-742', 'South Korea')],
#  'Feng, X.': [('100084', 'China'),
#   ('IL 60208', 'United States'),
#   ('IL 60208', 'United States'),
#   ('100084', 'China'),
#   ('310027', 'China'),
#   ('IL 60208', 'United States'),
#   ('IL 60208', 'United States'),
#   ('IL', 'United States'),
#   ('TN', 'United States'),
#   ('TN', 'United States'),
#   ('Beijing 100084', 'China')],
#  'Colombier, J.-P.': [('F-42023 Saint-Etienne', 'France'),
#   ('F-42023 Saint-Etienne', 'France')],
#  'Suiker, A.S.J.': [('Delft', 'Netherlands'), ('Eindhoven', 'Netherlands')],
#  'Liu, W.': [('Beijing', 'China'),
#   ('Beijing', 'China'),
#   ('Beijing', 'China'),
#   ('Beijing', 'China'),
#   ('IL 60439', 'United States'),
#   ('TN 37831', 'United States'),
#   ('MI 48824', 'United States'),
#   ('IL 60439', 'United States'),
#   ('40237 Düsseldorf', 'Germany'),
#   ('TN', 'United States'),
#   ('TN', 'United States'),
#   ('Jhongli', 'Taiwan'),
#   ('NM 87545', 'United States'),
#   ('IL', 'United States'),
#   ('IN', 'United States'),
#   ('TN', 'United States'),
#   ('TN', 'United States'),
#   ('IL', 'United States'),
#   ('TN 37831', 'United States'),
#   ('FL 32310', 'United States'),
#   ('IL 60439', 'United States'),
#   ('FL 32306', 'United States'),
#   ('TN 37831', 'United States'),
#   ('FL 32310', 'United States'),
#   ('IL 60439', 'United States'),
#   ('IL 60439', 'United States'),
#   ('TN 37831-6118', 'United States')],
#  'Spolenak, R.': [('Zurich CH-8093', 'Switzerland'),
#   ('CH-8093 Zurich', 'Switzerland'),
#   ('CH-5400 Baden', 'Switzerland'),
#   ('CA 94305', 'United States'),
#   ('CA 94720', 'United States'),
#   ('D-70569 Stuttgart', 'Germany'),
#   ('CA 94025', 'United States')],
#  'Adam, K.': [('WA', 'United States'), ('Dresden', 'Germany')],
#  'Espinosa, H.D.': [('IL 60208', 'United States'),
#   ('IL 60208', 'United States')],
#  'Dashwood, R.': [('Universitätsstr. 90 aBochum', 'Germany'),
#   ('Coventry', 'United Kingdom'),
#   ('Sheffield', 'United Kingdom'),
#   ('Coventry', 'United Kingdom')],
#  'Ningyun, W.': [('NE1 7RU England', 'United Kingdom')],
#  'Roessiger, J.': [('Tübingen', 'Germany'),
#   ('Bremerhaven', 'Germany'),
#   ('Bellaterra (Barcelona)', 'Spain'),
#   ('Los Alamos National LaboratoryNM', 'United States'),
#   ('VIC', 'Australia'),
#   ("38402 Saint-Martin d'Hères", 'France'),
#   ('75013 Paris', 'France'),
#   ('72074 Tübingen', 'Germany'),
#   ('48008 Bilbao', 'Spain'),
#   ('48011 Bilbao', 'Spain'),
#   ('08193 Bellaterra (Cerdanyola del V.)', 'Spain'),
#   ('NM 87545', 'United States'),
#   ('13402 Marseille cedex 20', 'France'),
#   ('Paris', 'France')],
#  'Chakrabarty, R.': [('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('TX', 'United States'),
#   ('TX', 'United States'),
#   ('Mumbai', 'India')],
#  'Hua, J.': [('44801 Bochum', 'Germany'),
#   ('Shaanxi 710055', 'China'),
#   ('Singapore 119260', 'Singapore'),
#   ('Singapore 117528', 'Singapore'),
#   ('119260', 'Singapore'),
#   ('117528', 'Singapore'),
#   ('Singapore 119260', 'Singapore'),
#   ('Singapore 117528', 'Singapore'),
#   ('Singapore 119260', 'Singapore'),
#   ('Singapore 117528', 'Singapore')],
#  'Liu, M.': [('Tokyo', 'Japan'),
#   ('NSW', 'Australia'),
#   ('Singapore', 'Singapore'),
#   ('NSW', 'Australia')],
#  'Steidl, G.': [('Kaiserslautern', 'Germany'),
#   ('Chinese University of Hong Kong', 'Hong Kong'),
#   ('Chemnitz', 'Germany')],
#  'Hong, S.S.': [('RI 02912', 'United States'),
#   ('9747 AG Groningen', 'Netherlands')],
#  'Pang, J.W.L.': [('090-8507', 'Japan'),
#   ('TN 37831', 'United States'),
#   ('TN 37831-6118', 'United States')],
#  'McMeeking, R.M.': [('Cambridge', 'United Kingdom'),
#   ('Tabriz', 'Iran'),
#   ('University of California Santa BarbaraCA', 'United States'),
#   ('University of California Santa BarbaraCA', 'United States'),
#   ('Aberdeen', 'United Kingdom')],
#  'Huang, Y.': [('100084', 'China'),
#   ('IL 60208', 'United States'),
#   ('IL 60208', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 60208', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 60208', 'United States'),
#   ('IL 60208', 'United States'),
#   ('100084', 'China'),
#   ('310027', 'China'),
#   ('IL 60208', 'United States'),
#   ('IL 60208', 'United States'),
#   ('100084', 'China'),
#   ('Hong Kong', 'Hong Kong'),
#   ('M60 1QD', 'United Kingdom'),
#   ('IL 60208', 'United States'),
#   ('IL 60208', 'United States'),
#   ('Ont. L8S 4L7', 'Canada'),
#   ('RI 02912', 'United States'),
#   ('IN 47907', 'United States'),
#   ('IL 60208', 'United States'),
#   ('A-8700 Leoben', 'Austria'),
#   ('100084', 'China'),
#   ('IL 60208', 'United States'),
#   ('IL 61801', 'United States'),
#   ('TN 37996', 'United States'),
#   ('100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Ont. L8S 4L7', 'Canada'),
#   ('CA 91125', 'United States'),
#   ('ND 58105', 'United States'),
#   ('RI 02912', 'United States'),
#   ('Beijing', 'China'),
#   ('IL', 'United States'),
#   ('NM', 'United States'),
#   ('IL 61801', 'United States'),
#   ('IL', 'United States'),
#   ('TN', 'United States'),
#   ('TN', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 60208', 'United States'),
#   ('10084', 'China'),
#   ('IL 61801', 'United States'),
#   ('RI 02912', 'United States'),
#   ('100084', 'China'),
#   ('CA 94305', 'United States'),
#   ('IL 61801', 'United States'),
#   ('PA 15069', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Ont. L8S 4L7', 'Canada'),
#   ('NM 87545', 'United States'),
#   ('IL 61801', 'United States'),
#   ('100084', 'China'),
#   ('CA 94305', 'United States'),
#   ('TN 37996', 'United States'),
#   ('TN 37831', 'United States'),
#   ('IL 61801', 'United States'),
#   ('TN 37996', 'United States'),
#   ('TN 37831', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Ont. K7L 5L9', 'Canada'),
#   ('IL 61801', 'United States'),
#   ('IN 47907', 'United States'),
#   ('Ont. K7L 5L9', 'Canada'),
#   ('Beijing 100084', 'China'),
#   ('D-70569 Stuttgart', 'Germany'),
#   ('CA 94305', 'United States'),
#   ('IL 61801', 'United States'),
#   ('IL 61801', 'United States'),
#   ('CA 94305', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('NM 87545', 'United States'),
#   ('Ont. K7L 5L9', 'Canada'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('IL 61801', 'United States'),
#   ('D-70569 Stuttgart', 'Germany'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('PA 15069', 'United States'),
#   ('Stuttgart', 'Germany'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('PA 15069', 'United States'),
#   ('NM 87545', 'United States'),
#   ('IL 61801', 'United States'),
#   ('IL 61801', 'United States'),
#   ('70569 Stuttgart', 'Germany'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100080', 'China'),
#   ('CA 94305', 'United States'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('PA 15069-0001', 'United States'),
#   ('IL 61801', 'United States'),
#   ('IL 61801', 'United States'),
#   ('PA 15069', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('CA 94305', 'United States'),
#   ('CA 94305', 'United States'),
#   ('Stuttgart', 'Germany'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('PA 15069', 'United States'),
#   ('CA 94305', 'United States'),
#   ('IL 61801', 'United States'),
#   ('IL 61801', 'United States'),
#   ('CA 94305', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('MI 49931', 'United States'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('MI 48121', 'United States'),
#   ('IL 61801', 'United States'),
#   ('Beijing', 'China'),
#   ('IL 61801', 'United States'),
#   ('Beijing', 'China'),
#   ('MI 49931', 'United States'),
#   ('MA 02138', 'United States'),
#   ('IL 61801', 'United States'),
#   ('Beijing', 'China'),
#   ('CA 94305', 'United States'),
#   ('IL 61801', 'United States'),
#   ('CA 94305', 'United States'),
#   ('MA 02138', 'United States'),
#   ('CA 94305', 'United States'),
#   ('IL 61801', 'United States'),
#   ('CA 94305', 'United States'),
#   ('IL 6180', 'United States'),
#   ('MI 49931', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('MI 49931', 'United States'),
#   ('IL 61801', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('MI 49931', 'United States'),
#   ('MI 49931', 'United States'),
#   ('Beijing 100084', 'China')],
#  'Suresh, K.G.': [('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('Mumbai', 'India'),
#   ('TX', 'United States'),
#   ('TX', 'United States'),
#   ('Mumbai', 'India')],
#  'Van Petegem, S.': [('Villigen PSI', 'Switzerland'),
#   ('Lausanne', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Villigen PSI', 'Switzerland'),
#   ('Baden-Dättwil', 'Switzerland'),
#   ('CH-5232 Villigen', 'Switzerland')],
#  'Gurao, N.P.': [('57045 Metz', 'France'), ('560012', 'India')],
#  'Axinte, D.A.': [('Thun', 'Switzerland'),
#   ('University of Nottingham', 'United Kingdom')],
#  'Pang, M.': [('Langfang 065000', 'China'), ('Langfang 065000', 'China')],
#  'Oztop, M.S.': [('NY', 'United States'),
#   ('UT 84602', 'United States'),
#   ('NY 10027', 'United States'),
#   ('NY 10027', 'United States'),
#   ('Busan 609-735', 'South Korea'),
#   ('BC V6T 1Z4', 'Canada')],
#  'Tsivinskii, S.V.': [('Ukrainian Academy of Sciences', 'Kharkov')],
#  'Chapman, S.J.': [('Oxford', 'United Kingdom'), ('Kowloon', 'Hong Kong')],
#  'Günther, C.': [('D-44780 Bochum', 'Germany')],
#  'Gueninchault, N.': [('Evry', 'France'),
#   ('Villeurbanne Cedex', 'France'),
#   ('Grenoble', 'France')],
#  'Voyiadjis, G.Z.': [('LA', 'United States'),
#   ('LA', 'United States'),
#   ('LA', 'United States'),
#   ('TX', 'United States'),
#   ('LA 70803', 'United States'),
#   ('Seoul', 'South Korea'),
#   ('TX 78712', 'United States'),
#   ('LA 70803', 'United States'),
#   ('70803', 'United States'),
#   ('70803', 'United States'),
#   ('LA 70803', 'United States'),
#   ('Hatay 31200', 'Turkey'),
#   ('TX 77843', 'United States'),
#   ('LA 70803', 'United States'),
#   ('Thessaloniki GR-54124', 'Greece'),
#   ('MI 49931', 'United States'),
#   ('Department of Civil Engineering', 'Texas A and M University'),
#   ('Louisiana State University',
#    'Department of Civil and Environmental Engineering'),
#   ('Aristotle University of Thessaloniki', 'Hellas'),
#   ('Michigan Technological University', 'United States'),
#   ('LA 70803', 'United States'),
#   ('CA 94550', 'United States')],
#  'Allain-Bonasso, N.': [('57045 Metz-Cedex', 'France'),
#   ('Washington State University', 'United States'),
#   ('WA 99164-2920', 'United States'),
#   ('Metz', 'France')],
#  'Upadhyay, M.': [('Metz Cedex', 'France'),
#   ('Metz Cedex', 'France'),
#   ('57045 Metz Cedex', 'France'),
#   ('57070 Metz Cedex', 'France'),
#   ('57070 Metz', 'France'),
#   ('57045 Metz Cedex', 'France')],
#  'Malygin, G.A.': [('194021 St. Petersburg', 'Russian Federation'),
#   ('St. Petersburg 194021', 'Russian Federation')],
#  'Jonsson, A.': [('SE-100 44 Stockholm', 'Sweden')],
#  'Thawinan, E.': [('Fürth', 'Germany'), ('Karlsruhe', 'Germany')],
#  'Grinfeld, M.A.': [('MD 21005', 'United States')],
#  'Aifantis, E.C.': [('TX 77843', 'United States'),
#   ('LA 70803', 'United States'),
#   ('Thessaloniki GR-54124', 'Greece'),
#   ('MI 49931', 'United States'),
#   ('Department of Civil Engineering', 'Texas A and M University'),
#   ('Louisiana State University',
#    'Department of Civil and Environmental Engineering'),
#   ('Aristotle University of Thessaloniki', 'Hellas'),
#   ('Michigan Technological University', 'United States'),
#   ('GR-54124 Thessaloniki', 'Greece'),
#   ('GR-54124 Thessaloniki', 'Greece'),
#   ('MI 49931', 'United States'),
#   ('IL', 'United States')],
#  'Sumino, K.': [('Sendai', 'Japan'),
#   ('Tokyo', 'Japan'),
#   ('Sendai', 'Japan'),
#   ('Ǒmiya', 'Japan')],
#  'Ota, K.': [('Osaka 561', 'Japan'), ('606 Kyoto', 'Japan')],
#  'Head, A.K.': [('3168', 'Australia'), ('Oxford', 'United Kingdom')],
#  'Jones, M.E.': [('NY 10027', 'United States'), ('NY 10027', 'United States')],
#  'Gupta, S.': [('IL', 'United States'),
#   ('Cedex', 'France'),
#   ('Bochum', 'Germany')],
#  'Kehagias, Th.': [('54124 Thessaloniki', 'Greece'),
#   ('81730 Munich', 'Germany'),
#   ('01099 Dresden', 'Germany')],
#  'Suzuki, K.': [('992-8510', 'Japan')],
#  'Martin, D.C.': [('MI 48109', 'United States'),
#   ('5600 KA Eindhoven', 'Netherlands'),
#   ('MI 48105', 'United States'),
#   ('MI 48109-2136', 'United States'),
#   ('MI 48121-2053', 'United States'),
#   ('MI 48109-2136', 'United States'),
#   ('MI 48109-2136', 'United States')],
#  'Guo, T.F.': [('IL 6180', 'United States'),
#   ('MI 49931', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('MI 49931', 'United States'),
#   ('Beijing 100084', 'China')],
#  'Nakata, H.': [('Tokyo 113', 'Japan')],
#  'Remmers, J.J.C.': [('Delft', 'Netherlands'),
#   ('Eindhoven', 'Netherlands'),
#   ('Cambridge', 'United Kingdom')],
#  'Li, X.': [("Xi'an", 'China')],
#  'Song, H.': [('Groningen', 'Netherlands'), ('Beijing', 'China')],
#  'Meisnar, M.': [('Oxford', 'United Kingdom'), ('Mihama', 'Japan')],
#  'Koiwa, K.': [('Aichi', 'Japan'),
#   ('Tokyo', 'Japan'),
#   ('Kanagawa', 'Japan'),
#   ('Kanagawa', 'Japan'),
#   ('Tokyo', 'Japan')],
#  'Weber, L.': [('CH-1015 Lausanne', 'Switzerland')],
#  'Sebald, T.': [('Swansea', 'United Kingdom'),
#   ('Munich', 'Germany'),
#   ('Munich', 'Germany')],
#  'Mistura, L.': [('14-00161', 'Italy')],
#  'Sahoo, D.': [('603 102', 'India')],
#  'Eve, S.': [('Oxford OX1 3PJ', 'United Kingdom'),
#   ('VIC 3010', 'Australia'),
#   ('F-38043 Grenoble', 'France'),
#   ('Oxford OX3 1PH', 'United Kingdom'),
#   ('14050 Caen Cedex 04', 'France')],
#  'Müller, S.': [('Leipzig', '7010'), ('pl. Dzerdžinskogo', 'Kharkov')],
#  'Robertson, C.': [("38402 Saint Martin d'Heres cedex", 'France'),
#   ('91191 Gif-sur-Yvette', 'France')],
#  'Flinn, J.E.': [('WA 99164-2920', 'United States'),
#   ('ID 83415', 'United States'),
#   ('ID 83402', 'United States')],
#  'Sangal, S.': [('Uttar Pradesh', 'India'), ('Uttar Pradesh', 'India')],
#  'Diaco, M.': [('80125 Naples', 'Italy')],
#  'Zabaras, N.': [('NY 14853-3801', 'United States')],
#  'Farahmand, H.': [('Kerman', 'Iran'), ('Kerman', 'Iran'), ('Tehran', 'Iran')],
#  'Wells, M.': [('ON', 'Canada'), ('MI', 'United States')],
#  'Zhang, Z.F.': [('Shenyang', 'China'),
#   ('Beijing', 'China'),
#   ('Shenyang', 'China'),
#   ('TN', 'United States')],
#  'Wriggers, P.': [('Hannover', 'Germany'),
#   ('Rondebosch', 'South Africa'),
#   ('Erlangen', 'Germany')],
#  'Chelladurai, I.': [('UT', 'United States'),
#   ('UT', 'United States'),
#   ('MI', 'United States'),
#   ('NM', 'United States'),
#   ('NH', 'United States')],
#  'Schmauder, S.': [('Isfahan 84156-83111', 'Iran'),
#   ('Stuttgart', 'Germany'),
#   ('Düsseldorf', 'Germany')],
#  'Weng, G.J.': [('NJ 08903', 'United States'),
#   ('CT 06520', 'United States'),
#   ('CT 06520', 'United States'),
#   ('CT 06520', 'United States')],
#  'Kovaleva, E.': [('Vienna', 'Austria'), ('Vienna', 'Austria')],
#  'Bachmann, F.': [('Freiberg', 'Germany'),
#   ('Chemnitz', 'Germany'),
#   ('Fife', 'United Kingdom'),
#   ('Roskilde', 'Denmark'),
#   ('Freiberg', 'Germany')],
#  'Hawreliak, J.': [('Oxford OX1 3PU', 'United Kingdom'),
#   ('CA 94550', 'United States'),
#   ('Berkshire RG7 4PR', 'United Kingdom')],
#  'Reynaud, S.': [('F-42023 Saint-Etienne', 'France'),
#   ('F-42023 Saint-Etienne', 'France')],
#  'Cho, H.-H.': [('Changwon', 'South Korea'),
#   ('OR', 'United States'),
#   ('Seoul 151-744', 'South Korea')],
#  'Han, S.-M.': [('NM 87545', 'United States'),
#   ('CA 94305', 'United States'),
#   ('Daejeon 305-701', 'South Korea'),
#   ('CA 94720', 'United States')],
#  'Pougis, A.': [('57045 Metz Cedex 1', 'France'),
#   ('Université de Lorraine', 'France'),
#   ('42023 Saint-Etienne Cedex 2', 'France')],
#  'Rosenthal, R.': [('Jerusalem', 'Israel'), ('Zürich', 'Switzerland')],
#  'Armstrong, D.E.J.': [('CA', 'United States'),
#   ('PA', 'United States'),
#   ('Oxford', 'United Kingdom'),
#   ('Oxford', 'United Kingdom'),
#   ('DE', 'United States'),
#   ('Oxford OX1 4JF', 'United Kingdom'),
#   ('LondonS W72AZ', 'United Kingdom')],
#  'Gorczyca, S.': [('31-059 Cracow', 'Poland')],
#  'Boeff, M.': [('Bochum', 'Germany')],
#  'Ji, J.': [('Jiangsu', 'China'), ('Hubei', 'China')],
#  'Bouhattate, J.': [('La Rochelle Cedex 01', 'France')],
#  'Ice, G.E.': [('TN', 'United States'),
#   ('TN', 'United States'),
#   ('Jhongli', 'Taiwan'),
#   ('NM 87545', 'United States'),
#   ('IL', 'United States'),
#   ('IN', 'United States'),
#   ('TN 37831', 'United States'),
#   ('TN 37996-0750', 'United States'),
#   ('CA 94551', 'United States'),
#   ('IL', 'United States'),
#   ('090-8507', 'Japan'),
#   ('TN 37831', 'United States'),
#   ('TN', 'United States'),
#   ('TN', 'United States'),
#   ('IL', 'United States'),
#   ('TN 37831', 'United States'),
#   ('FL 32310', 'United States'),
#   ('IL 60439', 'United States'),
#   ('IL 60439', 'United States'),
#   ('TN 37831-6118', 'United States')],
#  'Adedoyin, A.A.': [('MS', 'United States'),
#   ('NV', 'United States'),
#   ('MI', 'United States')],
#  'Carpick, R.W.': [('PA', 'United States'),
#   ('CA', 'United States'),
#   ('PA', 'United States'),
#   ('TX', 'United States'),
#   ('TN', 'United States')],
#  'Koseki, T.': [('Tokyo', 'Japan'),
#   ('NSW', 'Australia'),
#   ('Singapore', 'Singapore')],
#  'Belak, J.': [('TN 37831', 'United States'),
#   ('TN 37996-0750', 'United States'),
#   ('CA 94551', 'United States'),
#   ('IL', 'United States')],
#  'McGrath, K.M.': [('Cedex 05', 'France'), ('NJ 08544', 'United States')],
#  'Merklein, M.': [('91058 Erlangen', 'Germany')],
#  'Mohamed, M.S.': [('FL', 'United States'),
#   ('TN', 'United States'),
#   ('IL', 'United States'),
#   ('IN', 'United States'),
#   ('Jeddah', 'Saudi Arabia')],
#  'Llorens, M.-G.': [('Tübingen', 'Germany'),
#   ('Bremerhaven', 'Germany'),
#   ('Bellaterra (Barcelona)', 'Spain'),
#   ('Los Alamos National LaboratoryNM', 'United States'),
#   ('VIC', 'Australia')],
#  'Nastasi, M.': [('NM 87545', 'United States')],
#  'Lee, S.': [('Daejeon', 'South Korea'),
#   ('Pohang', 'South Korea'),
#   ('Daejeon', 'South Korea'),
#   ('Pohang', 'South Korea'),
#   ('Pohang', 'South Korea'),
#   ('Pohang', 'South Korea'),
#   ('Pohang', 'South Korea'),
#   ('Daejeon', 'South Korea'),
#   ('Material Research Department Hyundai Heavy IndustriesUlsan',
#    'South Korea'),
#   ('Daejeon', 'South Korea')],
#  'Littlewood, P.': [('Oxford OX1 3PH', 'United Kingdom')],
#  'Villani, A.': [('Metz', 'France'),
#   ('Saint-Etienne', 'France'),
#   ('Los Alamos National LaboratoryNM', 'United States')],
#  'Rosi, G.': [('45127 Essen', 'Germany'),
#   ('69621 Villeurbanne Cedex', 'France'),
#   ('00186 Roma', 'Italy'),
#   ('Creteil Codex 9410', 'France')],
#  'Moore, M.A.': [('Manchester M13 9PL', 'United Kingdom')],
#  'Shahba, A.': [('MD', 'United States')],
#  'Howison, S.D.': [('3168', 'Australia'), ('Oxford', 'United Kingdom')],
#  'Karki, B.B.': [("Villeneuve d'Ascq", 'France'),
#   ('Metz Cedex', 'France'),
#   ('LA', 'United States'),
#   ('LA', 'United States')],
#  'Arsenlis, A.': [('London SW7 2BX', 'United Kingdom'),
#   ('CA 9455-0808', 'United States'),
#   ('CA 94551', 'United States'),
#   ('MA 02139', 'United States'),
#   ('MA 01239', 'United States')],
#  'Persch, J.': [('Kaiserslautern', 'Germany'),
#   ('Chinese University of Hong Kong', 'Hong Kong'),
#   ('Chemnitz', 'Germany')],
#  'Joseph, D.S.': [('OH 43210', 'United States')],
#  'Zbib, H.M.': [('WA', 'United States'),
#   ('Doha', 'Qatar'),
#   ('WA', 'United States'),
#   ('Doha', 'Qatar'),
#   ('WA', 'United States'),
#   ('WA', 'United States'),
#   ('Doha', 'Qatar'),
#   ('WA 99164-2620', 'United States'),
#   ('WA 99164-2920', 'United States'),
#   ('WA 99164-2920', 'United States'),
#   ('Hokkaido 090-8507', 'Japan'),
#   ('223-8522', 'Japan'),
#   ('99164-2920', 'United States'),
#   ('Yokohama 223-8522', 'Japan'),
#   ('WA 99164-2920', 'United States')],
#  'Deng, Y.': [('Shenyang', 'China'), ('TX', 'United States')],
#  'Ma, W.': [('4000 Roskilde', 'Denmark')],
#  'Hantcherli, L.': [('Düsseldorf', 'Germany'), ('MI', 'United States')],
#  'Biswas, S.': [('Bangalore 560 012', 'India'),
#   ('Metz', 'France'),
#   ('F-57045 Metz', 'France')],
#  'Nikkel, D.J.': [('CA 94551-9900', 'United States'),
#   ('CA 94551', 'United States'),
#   ('Bath', 'United Kingdom')],
#  'Zhuang, Z.': [('Beijing 100084', 'China')],
#  'Yao, Z.-Q.': [('Dalian 116028', 'China')],
#  'Dluhoš, L.': [('DK-4000 Roskilde', 'Denmark'),
#   ('Moscow 119049', 'Russian Federation'),
#   ('Ufa 450000', 'Russian Federation'),
#   ('28906 Madrid', 'Spain'),
#   ('60438 Frankfurt am Main', 'Germany'),
#   ('Haifa 32000', 'Israel'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('CZ72525 Ostrava', 'Czech Republic'),
#   ('Leuven', 'Belgium')],
#  'Kirkland, A.I.': [('OX1 3PH', 'United Kingdom'),
#   ('SW72BP', 'United Kingdom')],
#  'Wallis, D.': [('Oxford', 'United Kingdom'),
#   ('London', 'United Kingdom'),
#   ('Oxford', 'United Kingdom'),
#   ('CA', 'United States'),
#   ('PA', 'United States'),
#   ('Oxford', 'United Kingdom'),
#   ('Oxford', 'United Kingdom'),
#   ('DE', 'United States'),
#   ('Oxford', 'United Kingdom'),
#   ('London', 'United Kingdom'),
#   ('Oxford', 'United Kingdom')],
#  'Remington, B.': [('Oxford OX1 3PU', 'United Kingdom'),
#   ('CA 94550', 'United States'),
#   ('Berkshire RG7 4PR', 'United Kingdom')],
#  'Grujicic, M.': [('SC 29634-0921', 'United States')],
#  'Gan, Z.': [('Wuhan 430074', 'China'),
#   ('Wuhan 430074', 'China'),
#   ('London E1 4NS', 'United Kingdom')],
#  'Tran, V.N.': [('Bochum', 'Germany'), ('Ho Chi Minh City', 'Viet Nam')],
#  'Kim, S.C.': [('Changwon', 'South Korea'),
#   ('OR', 'United States'),
#   ('Seoul 151-744', 'South Korea')],
#  'Warren, J.M.': [('CA', 'United States'),
#   ('PA', 'United States'),
#   ('Oxford', 'United Kingdom'),
#   ('Oxford', 'United Kingdom'),
#   ('DE', 'United States')],
#  'Kenik, E.A.': [('KY 40506-0027', 'United States'),
#   ('TN 37831-6064', 'United States')],
#  'McDowell, D.L.': [('NM 87545', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('GA 30332-0245', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('GA 30332-0245', 'United States'),
#   ('MS 39762', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('MD 21005-5069', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('CA 94550', 'United States'),
#   ('MD 21005-5069', 'United States'),
#   ('CA 94550', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('GA 30332-0405', 'United States'),
#   ('CA 94551-0969', 'United States'),
#   ('GA 30332-0405', 'United States')],
#  'Lad, A.': [('Bangalore', 'India'),
#   ('Bangalore', 'India'),
#   ('Mumbai', 'India'),
#   ('Bangalore', 'India')],
#  'Hardy, M.': [('Swansea SA2 8PP', 'United Kingdom'),
#   ('Cambridge CB3 0FS', 'United Kingdom'),
#   ('Derby DE24 8BJ', 'United Kingdom')],
#  'Nye, A.': [('PA', 'United States'), ('CA', 'United States')],
#  'Motz, C.': [('Saarbrücken', 'Germany'),
#   ('Leoben', 'Austria'),
#   ('Saarbrücken', 'Germany'),
#   ('Saarbrücken', 'Germany'),
#   ('Saarbrücken', 'Germany'),
#   ('A-8700 Leoben', 'Austria')],
#  'Shuklinov, A.V.': [('392000', 'Russian Federation')],
#  'Kositski, R.': [('Haifa', 'Israel'), ('Freiberg', 'Germany')],
#  'Schoeck, G.': [('Vienna', 'Austria'), ('A-1090 Vienna', 'Austria')],
#  'Ganghoffer, J.F.': [('54504 Vandoeuvre les Nancy Cedex', 'France'),
#   ('5600 MB Eindhoven', 'Netherlands')],
#  'Jackson, B.': [('MI 48824', 'United States'),
#   ('UT 84602', 'United States'),
#   ('VA 23662', 'United States')],
#  'Yi, G.': [('UT', 'United States'),
#   ('TN', 'United States'),
#   ('TN', 'United States'),
#   ('TN', 'United States')],
#  'Alabort, E.': [('Oxford', 'United Kingdom'), ('Oxford', 'United Kingdom')],
#  'Fundenberger, J.-J.': [('Metz', 'France'), ('Metz', 'France')],
#  'Barabash, R.I.': [('TN', 'United States'),
#   ('TN', 'United States'),
#   ('Jhongli', 'Taiwan'),
#   ('NM 87545', 'United States'),
#   ('IL', 'United States'),
#   ('IN', 'United States'),
#   ('TN 37831', 'United States'),
#   ('TN 37996-0750', 'United States'),
#   ('CA 94551', 'United States'),
#   ('IL', 'United States'),
#   ('090-8507', 'Japan'),
#   ('TN 37831', 'United States'),
#   ('TN', 'United States'),
#   ('TN', 'United States'),
#   ('IL', 'United States'),
#   ('TN 37831-6118', 'United States')],
#  'Nazari, A.': [('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh', 'Iran'),
#   ('Saveh Branch', 'Iran'),
#   ('Tehran', 'Iran'),
#   ('Saveh Branch', 'Iran'),
#   ('Tehran', 'Iran')],
#  'Zhang, J.': [('Shenyang', 'China'), ('TX', 'United States')],
#  'Bube, R.H.': [('CA 94305', 'United States')],
#  'Harrington, T.': [('CA', 'United States'),
#   ('CA', 'United States'),
#   ('CA', 'United States'),
#   ('NM', 'United States'),
#   ('CA', 'United States'),
#   ('NM', 'United States'),
#   ('CA', 'United States'),
#   ('NM', 'United States')],
#  'Littlewood, P.D.': [('Oxford', 'United Kingdom'),
#   ('Oxford', 'United Kingdom'),
#   ('Kongens Lyngby', 'Denmark')],
#  'Mukherjee, K.': [('D-52072 Aachen', 'Germany'),
#   ('D-52074 Aachen', 'Germany'),
#   ('D-52074 Aachen', 'Germany')],
#  'Patel, R.J.': [('Mumbai', 'India'), ('Mumbai', 'India')],
#  'Appolaire, B.': [('BP 87 91003Evry', 'France'),
#   ('Nancy', 'France'),
#   ('Châtillon Cedex', 'France'),
#   ('Villetaneuse', 'France'),
#   ('Châtillon', 'France')],
#  'Lazar, M.': [('Darmstadt', 'Germany'),
#   ('DIF', 'France'),
#   ('Essen', 'Germany'),
#   ('Iaşi', 'Romania'),
#   ('Iaşi', 'Romania'),
#   ('Bucharest', 'Romania'),
#   ('Darmstadt', 'Germany'),
#   ('Villeurbanne Cedex', 'France'),
#   ('Cisterna di Latina', 'Italy'),
#   ('D-64289 Darmstadt', 'Germany'),
#   ('D-04103 Leipzig', 'Germany'),
#   ('04109 Leipzig', 'Germany'),
#   ('D-70569 Stuttgart', 'Germany'),
#   ('D-04109 Leipzig', 'Germany')],
#  'Florando, J.N.': [('WA 99164-2920', 'United States'),
#   ('CH-8093 Zurich', 'Switzerland'),
#   ('CA 94551', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94551', 'United States'),
#   ('CA 94720', 'United States'),
#   ('OH 45433-7817', 'United States'),
#   ('CA 94550', 'United States'),
#   ('CA 94305-2205', 'United States')],
#  'Mianroodi, J.R.': [('Aachen', 'Germany'),
#   ('NM', 'United States'),
#   ('Düsseldorf', 'Germany')],
#  'Morse, T.L.': [('NY 10027', 'United States'), ('NY 10027', 'United States')],
#  'Weatherly, G.C.': [('Ont. L8S 4M1', 'Canada')],
#  'Suquet, P.': [('Paris', 'France'),
#   ('IL 61801', 'United States'),
#   ('13402 Marseille Cedex 20', 'France'),
#   ('PA 15213', 'United States'),
#   ("38402 Saint-Martin d'Hères", 'France'),
#   ('75013 Paris', 'France'),
#   ('72074 Tübingen', 'Germany'),
#   ('48008 Bilbao', 'Spain'),
#   ('48011 Bilbao', 'Spain'),
#   ('08193 Bellaterra (Cerdanyola del V.)', 'Spain'),
#   ('NM 87545', 'United States'),
#   ('13402 Marseille cedex 20', 'France'),
#   ('Paris', 'France')],
#  'Lassila, D.H.': [('WA 99164-2920', 'United States'),
#   ('CH-8093 Zurich', 'Switzerland'),
#   ('CA 94551', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94551', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94551-9900', 'United States'),
# ...
#   ('40237 Düsseldorf', 'Germany')],
#  'Gong, J.': [('Oxford', 'United Kingdom'), ('London', 'United Kingdom')],
#  'Nakamura, T.': [('Aichi', 'Japan'),
#   ('Tokyo', 'Japan'),
#   ('Kanagawa', 'Japan'),
#   ('Kanagawa', 'Japan'),
#   ('Tokyo', 'Japan')],
#  'Pandey, A.': [('Kanpur', 'India')],
#  'Miyamoto, G.': [('980-8577', 'Japan'),
#   ('226-8503', 'Japan'),
#   ('606-8501', 'Japan')],
#  'Song, J.': [('100084', 'China'),
#   ('IL 60208', 'United States'),
#   ('IL 61801', 'United States'),
#   ('TN 37996', 'United States'),
#   ('IL 60208', 'United States'),
#   ('10084', 'China'),
#   ('IL 61801', 'United States'),
#   ('RI 02912', 'United States')],
#  'Maciejewski, G.': [('00-049 Warsaw', 'Poland')],
#  'Nothwang, W.D.': [('MD 21005', 'United States')],
#  'Ninomiya, T.': [('Tokyo 113', 'Japan')],
#  'He, Y.': [('Wuhan 430074', 'China'),
#   ('Wuhan 430074', 'China'),
#   ('London E1 4NS', 'United Kingdom')],
#  'Lychev, S.A.': [('Moscow', 'Russian Federation')],
#  'Adak, A.': [('Bangalore', 'India'),
#   ('Bangalore', 'India'),
#   ('Mumbai', 'India'),
#   ('Bangalore', 'India')],
#  'Hielscher, R.': [('Kaiserslautern', 'Germany'),
#   ('Chinese University of Hong Kong', 'Hong Kong'),
#   ('Chemnitz', 'Germany'),
#   ('Freiberg', 'Germany'),
#   ('Chemnitz', 'Germany'),
#   ('Fife', 'United Kingdom'),
#   ('Roskilde', 'Denmark'),
#   ('Freiberg', 'Germany')],
#  'Zhu, Z.': [('Düsseldorf', 'Germany'), ('Oxford', 'United Kingdom')],
#  'Vecchio, K.S.': [('CA', 'United States'),
#   ('NM', 'United States'),
#   ('CA', 'United States'),
#   ('NM', 'United States'),
#   ('CA', 'United States'),
#   ('NM', 'United States')],
#  'Gil Sevillano, J.': [('20018 San Sebastián', 'Spain'),
#   ('20018 San Sebastián', 'Spain'),
#   ('20018 San Sebastián', 'Spain'),
#   ("38402 St Martin d'Heres Cedex", 'France')],
#  'El-Azab, A.': [('IN', 'United States'),
#   ('IN', 'United States'),
#   ('FL', 'United States'),
#   ('TN', 'United States'),
#   ('IL', 'United States'),
#   ('IN', 'United States'),
#   ('Jeddah', 'Saudi Arabia'),
#   ('TN 37831', 'United States'),
#   ('FL 32310', 'United States'),
#   ('IL 60439', 'United States'),
#   ('FL 32306', 'United States'),
#   ('TN 37831', 'United States'),
#   ('FL 32310', 'United States'),
#   ('IL 60439', 'United States'),
#   ('IL 60439', 'United States')],
#  'van Dommelen, J.A.W.': [('MB', 'Netherlands'),
#   ('5600 MB Eindhoven', 'Netherlands')],
#  'Zhao, X.': [('Beijing', 'China')],
#  'Bittner, F.': [('Dresden', 'Germany'),
#   ('Dresden', 'Germany'),
#   ('Freiberg', 'Germany')],
#  'Stupkiewicz, S.': [('Warsaw', 'Poland'), ('Warsaw', 'Poland')],
#  'Von Anthony, K.H.': [('Universität Stuttgart', 'Germany'),
#   ('Stuttgart', 'Germany')],
#  'Bergmann, R.': [('Kaiserslautern', 'Germany'),
#   ('Chinese University of Hong Kong', 'Hong Kong'),
#   ('Chemnitz', 'Germany')],
#  'Winther, G.': [('Kgs. Lyngby', 'Denmark'),
#   ('Grenoble', 'France'),
#   ('IL', 'United States'),
#   ('Kgs. Lyngby', 'Denmark'),
#   ('DK-4000 Roskilde', 'Denmark'),
#   ('Roskilde', 'Denmark')],
#  'Young, T.D.': [('02-106 Warsaw', 'Poland'),
#   ('GR-54124 Thessaloniki', 'Greece')],
#  'Tenev, T.G.': [('Mississippi State University StarkvilleMS',
#    'United States'),
#   ('Mississippi State University StarkvilleMS', 'United States')],
#  'Davidson, S.M.': [('University of Manchester', 'United Kingdom'),
#   ('University of Islamabad', 'Pakistan')],
#  'Bradford, L.T.': [('WA 99164-2920', 'United States'),
#   ('UT 84020', 'United States'),
#   ('ID', 'United States')],
#  'Saidi, A.R.': [('Kerman', 'Iran'), ('Kerman', 'Iran'), ('Tehran', 'Iran')],
#  'Wu, N.Q.': [('PA 15261', 'United States'), ('Alta.', 'Canada')],
#  'Wulfinghoff, S.': [('Aachen', 'Germany'),
#   ('Karlsruhe', 'Germany'),
#   ('Karlsruhe', 'Germany'),
#   ('Aachen', 'Germany'),
#   ('Düsseldorf', 'Germany'),
#   ('Leoben', 'Austria'),
#   ('CA', 'United States'),
#   ('Karlsruhe', 'Germany'),
#   ('Karlsruhe', 'Germany'),
#   ('Evry Cedex', 'France'),
#   ('Karlsruhe Institute of Technology (KIT)', 'Germany'),
#   ('76131 Karlsruhe', 'Germany'),
#   ('Karlsruhe', 'Germany')],
#  'Monavari, M.': [('Fürth', 'Germany'), ('90762 Fürth', 'Germany')],
#  'LeSar, R.': [('CA 90095', 'United States'), ('NM 87545', 'United States')],
#  'Turnbull, A.': [('Swansea', 'United Kingdom'),
#   ('Middlesex', 'United Kingdom')],
#  'Sedláček, R.': [('166 29 Prague', 'Czech Republic'),
#   ('186 75 Prague', 'Czech Republic'),
#   ('182 08 Prague', 'Czech Republic'),
#   ('85747 Garching', 'Germany'),
#   ('85747 Garching', 'Germany'),
#   ('85747 Garching', 'Germany'),
#   ('D-85747 Garching', 'Germany'),
#   ('CZ-166 29 Prague', 'Czech Republic'),
#   ('D-91058 Erlangen', 'Germany'),
#   ('D-91058 Erlangen', 'Germany'),
#   ('F-91003 Evry', 'France')],
#  'Sarac, A.': [('NY', 'United States'), ('NY', 'United States')],
#  'Zhang, W.-Z.': [('Beijing', 'China')],
#  'Kumar, M.': [('TN 37831', 'United States'),
#   ('TN 37996-0750', 'United States'),
#   ('CA 94551', 'United States'),
#   ('IL', 'United States'),
#   ('WA 99164-2920', 'United States'),
#   ('UT 84020', 'United States'),
#   ('CA 94550', 'United States')],
#  'Cho, Y.-G.': [('Changwon', 'South Korea'),
#   ('OR', 'United States'),
#   ('Seoul 151-744', 'South Korea')],
#  'Park, N.': [('Oxford OX1 3PU', 'United Kingdom'),
#   ('CA 94550', 'United States'),
#   ('Berkshire RG7 4PR', 'United Kingdom')],
#  'Rao, S.I.': [('OH 45433-7817', 'United States'),
#   ('OH 45432-1894', 'United States'),
#   ('IL 60208-3108', 'United States')],
#  'Ludwig, W.': [('Evry', 'France'),
#   ('Villeurbanne Cedex', 'France'),
#   ('Grenoble', 'France')],
#  'Maki, T.': [('980-8577', 'Japan'),
#   ('226-8503', 'Japan'),
#   ('606-8501', 'Japan')],
#  'Maurice, C.': [('F-42023 Saint-Etienne', 'France'),
#   ('F-42023 Saint-Etienne', 'France')],
#  'Campbell, G.H.': [('CA 94551-9900', 'United States'),
#   ('CA 94551', 'United States'),
#   ('Bath', 'United Kingdom')],
#  'Gey, N.': [('Metz Cedex 1', 'France'),
#   ('Saint-Paul-Lez-Durance', 'France'),
#   ('Université de Lorraine', 'France')],
#  'Bertin, N.': [('57070 Metz', 'France'), ('NM 87545', 'United States')],
#  'Sun, X.-Y.': [("Villeneuve d'Ascq", 'France'),
#   ('Metz Cedex', 'France'),
#   ('LA', 'United States'),
#   ('LA', 'United States'),
#   ("Villeneuve d'Ascq", 'France'),
#   ('Metz Cedex', 'France')],
#  'Smyshlyaev, V.P.': [('CA 94551-9900', 'United States'),
#   ('CA 94551', 'United States'),
#   ('Bath', 'United Kingdom')],
#  'Hirsch, P.B.': [('616 62 Brno', 'Czech Republic'),
#   ('OX1 3PH', 'United Kingdom'),
#   ('Hamilton L8S 4L7', 'Canada'),
#   ('PA 19104', 'United States')],
#  'Nyilas, R.D.': [('Zurich CH-8093', 'Switzerland'),
#   ('CH-8093 Zurich', 'Switzerland'),
#   ('CH-5400 Baden', 'Switzerland')],
#  'Li, H.': [('Beijing', 'China'),
#   ('London', 'United Kingdom'),
#   ('Düsseldorf', 'Germany')],
#  'Feng, S.-S.': [('730000', 'China'), ('100080', 'China')],
#  'Tan, J.-S.': [('Langfang 065000', 'China'), ('Langfang 065000', 'China')],
#  'Lesar, R.': [('IA 50011', 'United States'),
#   ('OH 45433-7817', 'United States'),
#   ('NM 87545', 'United States')],
#  'Anand, L.': [('MA 02139', 'United States'),
#   ('Cambridge', 'United States'),
#   ('PA 15213', 'United States'),
#   ('MA 02139', 'United States'),
#   ('PA', 'United States'),
#   ('MA', 'United States')],
#  'Kobelev, V.': [('Siegen', 'Germany')],
#  'Peerlings, R.H.J.': [('Delft', 'Netherlands'),
#   ('Eindhoven', 'Netherlands'),
#   ('5600 MB Eindhoven', 'Netherlands'),
#   ('Singapore', 'Singapore'),
#   ('5600 MB Eindhoven', 'Netherlands'),
#   ('30167 Hannover', 'Germany')],
#  'Landon, C.': [('UT 84602', 'United States'),
#   ('UT 84602', 'United States'),
#   ('UT', 'United States')],
#  'Petryk, H.': [('Warsaw', 'Poland'), ('Warsaw', 'Poland')],
#  'Onaka, S.': [('Yokohama', 'Japan'), ('Kimitsu', 'Japan')],
#  'Li, F.': [("Xi'an 710072", 'China')],
#  'Kodera, K.': [('Nagoya 464-8603', 'Japan'), ('Nagoya 464-8603', 'Japan')],
#  'De Jaeger, J.': [('Châtenay-Malabry', 'France'),
#   ('Orsay', 'France'),
#   ('Orsay', 'France'),
#   ('Gif-sur-Yvette', 'France'),
#   ('Bologne', 'France')],
#  'Di Gioacchino, F.': [('Cambridge', 'United Kingdom'),
#   ('Barcelona', 'Spain'),
#   ('Swansea SA2 8PP', 'United Kingdom'),
#   ('Cambridge CB3 0FS', 'United Kingdom'),
#   ('Derby DE24 8BJ', 'United Kingdom')],
#  'Sweeney, C.A.': [('Galway', 'Ireland'),
#   ('Galway', 'Ireland'),
#   ('London', 'United Kingdom')],
#  'Taheri-Nassaj, N.': [('WA', 'United States')],
#  'Cleveringa, H.H.M.': [('Delft', 'Netherlands'),
#   ('RI 02912', 'United States')],
#  'Morandotti, M.': [('Lisboa', 'Portugal'),
#   ('Lisboa', 'Portugal'),
#   ('Garching bei München', 'Germany'),
#   ('PA', 'United States')],
#  'Tamura, N.': [('Karlsruhe', 'Germany'),
#   ('Karlsruhe', 'Germany'),
#   ('Aachen', 'Germany'),
#   ('Düsseldorf', 'Germany'),
#   ('Leoben', 'Austria'),
#   ('CA', 'United States'),
#   ('NM 87545', 'United States'),
#   ('ON N2L 3G1', 'Canada'),
#   ('CA 91125', 'United States'),
#   ('Daejeon 305-701', 'South Korea'),
#   ('CA 94720', 'United States'),
#   ('NM 87545', 'United States'),
#   ('CA 94305', 'United States'),
#   ('Daejeon 305-701', 'South Korea'),
#   ('CA 94720', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94720', 'United States'),
#   ('Ont. N2L 3G1', 'Canada'),
#   ('CA 91125', 'United States'),
#   ('NM 87545', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94305', 'United States'),
#   ('CA 94088', 'United States'),
#   ('CA', 'United States'),
#   ('Seoul', 'South Korea'),
#   ('CA 94720', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94551', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94305', 'United States'),
#   ('CA 91125', 'United States'),
#   ('CA 94720', 'United States'),
#   ('CA 94305', 'United States'),
#   ('CA 94720', 'United States'),
#   ('D-70569 Stuttgart', 'Germany'),
#   ('CA 94025', 'United States')],
#  'Panchenko, A.': [('WA', 'United States'), ('WA', 'United States')],
#  'Wang, H.': [('Kowloon', 'Hong Kong'),
#   ('650221 Yunnan', 'China'),
#   ('Guangzhou 510632', 'China'),
#   ('Shenyang 110016', 'China'),
#   ('Beijing 100039', 'China'),
#   ('100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Ont. L8S 4L7', 'Canada'),
#   ('CA 91125', 'United States'),
#   ('ND 58105', 'United States'),
#   ('RI 02912', 'United States')],
#  'Mesarovic, S.D.': [('WA', 'United States'),
#   ('Evry Cedex', 'France'),
#   ('Belgrade', 'Serbia')],
#  'Wright, S.I.': [('UT', 'United States'),
#   ('UT', 'United States'),
#   ('PA', 'United States'),
#   ('OH', 'United States'),
#   ('WA 99164-2920', 'United States'),
#   ('UT 84020', 'United States'),
#   ('CA 94550', 'United States')],
#  'Koch, J.A.': [('CA 94551', 'United States')],
#  'Cermelli, P.': [('10123 Torino', 'Italy'),
#   ('PA 15213-3190', 'United States'),
#   ('Torino', 'Italy'),
#   ('PA 15213-3190', 'United States'),
#   ('Torino', 'Italy'),
#   ('Norwich', 'United Kingdom'),
#   ('I-10123 Torino', 'Italy'),
#   ('Norwich NR4 7TJ', 'United Kingdom'),
#   ('10123', 'Italy'),
#   ('Pennsylvania', 'United States'),
#   ('10123', 'Italy'),
#   ('PA 15213', 'United States')],
#  'Lin, J.-Y.': [('Tokyo', 'Japan'),
#   ('NSW', 'Australia'),
#   ('Singapore', 'Singapore')],
#  'Elkhodary, K.I.': [('American University in Cairo', 'Egypt'),
#   ('NC 27695-7910', 'United States')],
#  'Hochrainer, T.': [('Graz', 'Austria'),
#   ('Bremen', 'Germany'),
#   ('76131 Karlsruhe', 'Germany'),
#   ('FL 32310', 'United States'),
#   ('Edinburgh EH93JL', 'United Kingdom'),
#   ('79108 Freiburg', 'Germany'),
#   ('76131 Karlsruhe', 'Germany'),
#   ('79108 Freiburg', 'Germany'),
#   ('EH9 3JL', 'United Kingdom'),
#   ('76131 Karlsruhe', 'Germany'),
#   ('Edinburgh EH93JL', 'United Kingdom'),
#   ('79108 Freiburg', 'Germany')],
#  'Zaefferer, S.': [('Beijing', 'China'),
#   ('London', 'United Kingdom'),
#   ('Düsseldorf', 'Germany'),
#   ('Beijing', 'China'),
#   ('London', 'United Kingdom'),
#   ('Düsseldorf', 'Germany'),
#   ('Düsseldorf', 'Germany'),
#   ('Oxford', 'United Kingdom'),
#   ('Dusseldorf', 'Germany'),
#   ('40237 Düsseldorf', 'Germany'),
#   ('40237 Düsseldorf', 'Germany')],
#  'Goriely, A.': [('GA 30332', 'United States'),
#   ('Oxford OX1 3LB', 'United Kingdom')],
#  'Liu, Y.': [('Harbin 150001', 'China')],
#  'Lawrence, D.P.': [('MI 48109', 'United States'),
#   ('5600 KA Eindhoven', 'Netherlands'),
#   ('MI 48105', 'United States')],
#  'Iza-Mendia, A.': [('Basque Country', 'Spain')],
#  'Cheng, J.': [('MD', 'United States')],
#  "Psakh'E, S.": [('DK-4000 Roskilde', 'Denmark'),
#   ('Moscow 119049', 'Russian Federation'),
#   ('Ufa 450000', 'Russian Federation'),
#   ('28906 Madrid', 'Spain'),
#   ('60438 Frankfurt am Main', 'Germany'),
#   ('Haifa 32000', 'Israel'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('CZ72525 Ostrava', 'Czech Republic'),
#   ('Leuven', 'Belgium')],
#  'Chakraborty, P.': [('OH 43210', 'United States')],
#  'Khosravani, A.': [('VA', 'United States'),
#   ('UT', 'United States'),
#   ('NJ', 'United States'),
#   ('GA', 'United States'),
#   ('UT', 'United States'),
#   ('UT', 'United States'),
#   ('MI', 'United States')],
#  'Kružík, M.': [('Freiburg i. Br.', 'Germany'),
#   ('Praha 8', 'Czech Republic'),
#   ('Praha 6', 'Czech Republic'),
#   ('166 29 Prague', 'Czech Republic'),
#   ('186 75 Prague', 'Czech Republic'),
#   ('182 08 Prague', 'Czech Republic'),
#   ('85747 Garching', 'Germany')],
#  'Dey, I.': [('Bangalore', 'India'),
#   ('Bangalore', 'India'),
#   ('Mumbai', 'India'),
#   ('Bangalore', 'India')],
#  'Martínez-Esnaola, J.M.': [('20018 San Sebastián', 'Spain'),
#   ('20018 San Sebastián', 'Spain'),
#   ("38402 St Martin d'Heres Cedex", 'France')],
#  'Varadhan, S.N.': [('IL 61801', 'United States'),
#   ('PA 15213', 'United States'),
#   ('57045 Metz Cedex', 'France')],
#  'Kim, M.': [('Seoul 151-744', 'South Korea'),
#   ('Seoul 151-744', 'South Korea')],
#  'Li, N.': [('NM 87545', 'United States'),
#   ('CA 94305', 'United States'),
#   ('Daejeon 305-701', 'South Korea'),
#   ('CA 94720', 'United States')],
#  'Shi, M.X.': [('IL 61801', 'United States'),
#   ('IL 61801', 'United States'),
#   ('D-70569 Stuttgart', 'Germany'),
#   ('IL 61801', 'United States'),
#   ('CA 94305', 'United States'),
#   ('Beijing 100084', 'China'),
#   ('IL 61801', 'United States'),
#   ('Beijing', 'China'),
#   ('IL 61801', 'United States'),
#   ('Beijing', 'China')],
#  'Stoller, R.E.': [('Shenyang', 'China'), ('TN', 'United States')],
#  'Miehe, C.': [('Stuttgart', 'Germany'),
#   ('Stuttgart', 'Germany'),
#   ('70569 Stuttgart', 'Germany'),
#   ('70569 Stuttgart', 'Germany'),
#   ('70569 Stuttgart', 'Germany'),
#   ('University of Stuttgart', 'Germany'),
#   ('70550 Stuttgart', 'Germany')],
#  'Chen, X.': [('NY 10027', 'United States'),
#   ('NY 10027', 'United States'),
#   ('NY 10003', 'United States'),
#   ('NY 10027', 'United States'),
#   ('NY 10027', 'United States')],
#  'Kruzic, J.J.': [('IN', 'United States'),
#   ('IN', 'United States'),
#   ('New South Wales', 'Australia')],
#  'Das, A.': [('CA 91125', 'United States'), ('PA 15213', 'United States')],
#  'Panoskaltsis, V.P.': [('WA 98607', 'United States'),
#   ('OH 44106-7201', 'United States')],
#  'Enikeev, N.': [('DK-4000 Roskilde', 'Denmark'),
#   ('Moscow 119049', 'Russian Federation'),
#   ('Ufa 450000', 'Russian Federation'),
#   ('28906 Madrid', 'Spain'),
#   ('60438 Frankfurt am Main', 'Germany'),
#   ('Haifa 32000', 'Israel'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('Tomsk 634050', 'Russian Federation'),
#   ('CZ72525 Ostrava', 'Czech Republic'),
#   ('Leuven', 'Belgium')],
#  'Nagahama, H.': [('Sendai 980-8578', 'Japan'),
#   ('Sendai 980', 'Japan'),
#   ('Sendai 980', 'Japan')],
#  'Sevostianov, I.': [('MA 02155', 'United States'),
#   ('NM 88003-8001', 'United States')],
#  'Komninou, Ph.': [('54124 Thessaloniki', 'Greece'),
#   ('81730 Munich', 'Germany'),
#   ('01099 Dresden', 'Germany'),
#   ('GR-54124 Thessaloniki', 'Greece'),
#   ('GR-54124 Thessaloniki', 'Greece'),
#   ('MI 49931', 'United States')],
#  'Truster, T.J.': [('TN', 'United States')],
#  'Hütter, M.': [('5600 MB Eindhoven', 'Netherlands'),
#   ('5600 MB Eindhoven', 'Netherlands')],
#  'Mapoles, E.A.': [('CA 94551', 'United States')],
#  'Proudhon, H.': [('Evry', 'France'),
#   ('Villeurbanne Cedex', 'France'),
#   ('Grenoble', 'France')],
#  'Aouadi, S.': [('TX', 'United States')],
#  'Feyel, F.': [('F-92322 Châtillon cedex', 'France'),
#   ('F-92322 Châtillon cedex', 'France')],
#  'Ahmadi, S.': [('UT 84602', 'United States'), ('UT', 'United States')],
#  ...}

# %%
def articleToDict( article ):

    dico = {}
    dico['title'] = article.title
    dico['nbrCitation'] = article.nbrCitation
    dico['journal'] = article.journal
    dico['year'] = article.year
    dico['authors'] = '; '.join(article.authors)
    return dico

# %%
groupId = 0
dfGrp = pd.DataFrame.from_records( [articleToDict(biblio.getArticleFromKey(key)) for key in groupByAuthors[groupId]] )
dfGrp

# %% [markdown]
# ### Authors and affiliation

# %%
groupId = 6
for a in groupByAuthors[groupId]:
    print('; '.join( biblio.getArticleFromKey(a).authors ))
    print( [ parseAffiliation( aff ) for aff in  biblio.getArticleFromKey(a).affiliation ] )
# Out:
# Hochrainer, T.; Zaiser, M.; Gumbsch, P.
# [('76131 Karlsruhe', 'Germany'), ('Edinburgh EH93JL', 'United Kingdom'), ('79108 Freiburg', 'Germany')]
# Sandfeld, S.; Hochrainer, T.; Zaiser, M.; Gumbsch, P.
# [('76131 Karlsruhe', 'Germany'), ('FL 32310', 'United States'), ('Edinburgh EH93JL', 'United Kingdom'), ('79108 Freiburg', 'Germany')]
# Wu, R.; Zaiser, M.; Sandfeld, S.
# [('Fürth', 'Germany'), ('Freiberg', 'Germany')]
# Schulz, K.; Dickel, D.; Schmitt, S.; Sandfeld, S.; Weygand, D.; Gumbsch, P.
# [('76131 Karlsruhe', 'Germany'), ('90762 Fürth', 'Germany'), ('79108 Freiburg', 'Germany')]
# Monavari, M.; Sandfeld, S.; Zaiser, M.
# [('Fürth', 'Germany')]
# Sandfeld, S.; Hochrainer, T.; Gumbsch, P.; Zaiser, M.
# [('76131 Karlsruhe', 'Germany'), ('79108 Freiburg', 'Germany'), ('EH9 3JL', 'United Kingdom')]
# Schulz, K.; Sudmanns, M.; Gumbsch, P.
# [('Karlsruhe', 'Germany'), ('Freiburg', 'Germany')]
# Sandfeld, S.; Monavari, M.; Zaiser, M.
# [('90762 Fürth', 'Germany')]

# %%
distanceByCoauthors.number_of_nodes()
# Out:
# 159
